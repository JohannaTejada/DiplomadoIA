# %% [markdown]
# <a href="https://colab.research.google.com/github/JohannaTejada/DiplomadoIA/blob/main/ProblemaIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Comentarios de mas de ua linea
Subir archivo desde guthub
'''

#Importar archivo desde github
#Importa libreria de pandas

import pandas as pd
url = 'https://github.com/JohannaTejada/DiplomadoIA/raw/refs/heads/main/DB_diplomatura_%20IA_11042025_2.csv'

df = pd.read_csv(url, sep=";")
df
# Out:
#     ID_Paciente  Edad  MMSE  MoCA  Volumen_Hipocampo  Años_Diagnostico  \
# 0           NaN    72    29    27                5.2                 3
# 1           2.0    68    30    28                5.4                 2
# 2           3.0    65    28    26                5.0                 1
# 3           4.0    60    30    30                5.6                 1
# 4           5.0    75    28    25                4.8                 2
# 5           6.0    80    29    28                5.3                 3
# 6           7.0    67    30    29                5.5                 4
# 7           8.0    70    27    24                5.1                 5
# 8           9.0    64    30    29                5.4                 0
# 9          10.0    66    29    28                5.2                 2
# 10         11.0    55    15    12                3.5                 8
# 11         12.0    78    12    14                2.8                10
# ...
