# %% [markdown]
# <a href="https://colab.research.google.com/github/JohannaTejada/DiplomadoIA/blob/main/1_TalentoTech_IA_Explorador_Mision_1%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt='CC' height='30px' src='https://creativecommons.org/images/deed/cc_blue_x2.png' align='left' hspace='0px' vspace='0px'>
# <img alt='Attribution' height='30px' src='https://creativecommons.org/images/deed/attribution_icon_blue_x2.png' align='left' hspace='0px' vspace='0px'>
# <img alt='NC' height='30px' src='https://creativecommons.org/images/deed/nc_blue_x2.png' align='left' hspace='0px' vspace='0px'>
# <img alt='SA' height='30px' src='https://creativecommons.org/images/deed/sa_blue_x2.png' align='left' hspace='0px' vspace='0px'>
# </p>
# <br>
# <div align='right'>
# <h1> <b> Inteligencia Artificial - Explorador</h1>
# <h2> 🤖 MISION 1 </font><br> Fundamentos del Aprendizaje Automático y Preprocesamiento de Datos</b>
# <h2> <font size=5>Ing. Julián Darío Giraldo Ocampo M.Sc.</font></H3>
#   <a href='mailto:julian.giraldoo@udea.edu.co'> ✉ [ julian.giraldoo@udea.edu.co ]</a> |
#   <a href='mailto:ingenieria@juliangiraldo.co'> ✉ [ ingenieria@juliangiraldo.co ]</a>
# </div>
#
# <br>
#
# *Contenido Digital para el Bootcamp de Talento Tech - Region 2*
#
# ---

# %% [markdown]
# # <strong> Introducción a la IA y  Tipos de Aprendizaje </strong>

# %% [markdown]
# ## <strong> 📜Historia y Evolución de la IA </strong>
#
# La historia de la inteligencia artificial (IA) comenzó en la antigüedad con mitos sobre seres artificiales inteligentes, pero su desarrollo moderno se remonta a mediados del siglo XX. En la década de 1940, la invención de la computadora digital programable sentó las bases para la IA. En 1950, Alan Turing publicó su artículo "Computing Machinery and Intelligence", introduciendo el concepto del test de Turing, que evalúa la capacidad de una máquina para exhibir comportamiento inteligente indistinguible del de un ser humano.
#
# En 1956, la conferencia en Dartmouth College marcó el nacimiento formal de la IA como disciplina académica, liderada por John McCarthy, Marvin Minsky, Nathaniel Rochester y Claude Shannon. La IA ha experimentado avances significativos, incluyendo el desarrollo del aprendizaje automático y el aprendizaje profundo, así como períodos de desilusión financiera conocidos como los "inviernos de la IA".

# %% [markdown]
# ## <strong> 🫧 Diferencias entre IA, ML y Deep Learning </strong>
#
# - **Inteligencia Artificial (IA):** Se refiere a la creación de sistemas que pueden realizar tareas que normalmente requieren inteligencia humana. La IA abarca un amplio rango de técnicas y disciplinas, desde el procesamiento del lenguaje natural hasta la visión artificial.
#
# - **Machine Learning (ML):** Es un subconjunto de la IA que se enfoca en el desarrollo de algoritmos que permiten a las máquinas aprender de los datos sin ser programadas explícitamente. El ML se utiliza para predecir resultados o clasificar datos.
#
# - **Deep Learning (DL):** Es una rama del ML que utiliza redes neuronales artificiales para analizar datos complejos, como imágenes y audio. El DL ha sido crucial en avances recientes en áreas como la visión artificial y el procesamiento del lenguaje natural.

# %% [markdown]
# ## <strong> 🧑🏻‍🏫Tipos de Aprendizaje </strong>
#
# - **Aprendizaje Supervisado**: El aprendizaje supervisado es un paradigma donde el modelo es entrenado con datos etiquetados. Se utilizan entradas y sus correspondientes salidas deseadas para aprender una función de mapeo.
#
#     - Regresión Lineal para predecir valores clínicos en pacientes.
#
#     - Clasificación con Naive Bayes para detectar enfermedades en imágenes médicas.
#
# - **Aprendizaje No Supervisado**: En el aprendizaje no supervisado, los datos no están etiquetados. El modelo encuentra patrones ocultos o estructuras en los datos.
#
#  - K-Means para segmentación de pacientes según características clínicas.
#
#  - Análisis de Componentes Principales (PCA) para reducción de dimensionalidad en datos de laboratorio.
#
# - **Aprendizaje Reforzado**: El aprendizaje reforzado se basa en la interacción de un agente con un entorno para maximizar una recompensa.
#
#  - Algoritmos de IA para optimizar planes de tratamiento personalizados.
#
#  - Control de dispositivos médicos autónomos.

# %% [markdown]
# # <strong> 👨🏻‍⚕️Aplicaciones de la IA en Medicina </strong>
#
# La IA ha transformado la medicina en varias áreas clave:
#
# - **Diagnóstico Asistido por Computadora:** Las redes neuronales se utilizan para analizar imágenes médicas, como radiografías y resonancias magnéticas, para detectar enfermedades como el cáncer más rápidamente y con mayor precisión.
#
# - **Predicción de Resultados Clínicos:** Los modelos de aprendizaje automático pueden predecir el riesgo de complicaciones o la probabilidad de recuperación de pacientes basándose en sus historias clínicas y datos demográficos.
#
# - **Desarrollo de Medicamentos:** La IA ayuda a identificar nuevos compuestos farmacéuticos y a acelerar el proceso de descubrimiento de fármacos mediante el análisis de grandes conjuntos de datos químicos y biológicos.

# %% [markdown]
# # <strong> Historia y Ciclo de Vida de una Aplicación de Aprendizaje de Máquina </strong>
#
# <center><img src="https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/Ciclo_Vida_Aplicacion_ML.png" width=65%> </center>
#
# El Aprendizaje de Máquina **(ML)** ha evolucionado significativamente desde sus inicios, pasando de ser una disciplina académica a una herramienta fundamental en la industria. A lo largo de su historia, el desarrollo de aplicaciones de ML ha seguido un ciclo de vida bien definido que garantiza la eficacia y la eficiencia de los modelos. A continuación, se detalla cada etapa de este ciclo:
#
# <font size = 5>1. Investigación y Planificación </font>
#
# Aunque la mayoría de la literatura no lo considera, es útil incluir una fase inicial de investigación y planificación. Esto implica:
#
# - Explorar el dominio,
# - Identificar oportunidades potenciales.
# - Definir los objetivos generales del proyecto.
#
# <font size = 5>2. Identificación del Problema </font>
#
# La primera etapa implica identificar un problema o una oportunidad que pueda ser abordada mediante el aprendizaje de máquina. Esto requiere una comprensión profunda del negocio o del dominio en el que se está trabajando. Algunas preguntas clave para esta etapa incluyen:
#
# - ¿Qué problema estamos tratando de resolver?
# - ¿Cuáles son los objetivos clave?
# - ¿Qué datos están disponibles para abordar este problema?
#
# <font size = 5>3. Recolección de Datos </font>
#
# Una vez identificado el problema, la siguiente etapa es la recolección de datos relevantes. Esto puede incluir datos estructurados, no estructurados o semiestructurados, dependiendo del tipo de problema. La calidad y la cantidad de los datos son cruciales para el éxito del modelo.
#
# - Fuentes de datos: Bases de datos, sensores, APIs, archivos CSV, etc.
# - Consideraciones éticas: Privacidad, consentimiento, sesgo en los datos.
#
# <font size = 5>4. Preparación de Datos </font>
#
# La preparación de los datos es una de las etapas más importantes y consumidoras de tiempo en el ciclo de vida de una aplicación de ML. Incluye limpieza, transformación y selección de características relevantes.
#
# - Limpieza de datos: Manejo de valores faltantes, eliminación de datos duplicados.
# - Transformación de datos: Normalización, escalado, codificación de variables categóricas.
# - Selección de características: Identificar las variables más relevantes para el modelo.
#
# <font size = 5>5. Ingeniería de Modelos </font>
#
# En esta etapa, se desarrollan y entrenan los modelos de aprendizaje de máquina. Esto puede incluir desde modelos simples como regresión lineal hasta modelos más complejos como redes neuronales profundas.
#
# - Selección del algoritmo: Depende del tipo de problema (clasificación, regresión, clustering) y de los datos disponibles.
# - Entrenamiento del modelo: Uso de conjuntos de entrenamiento y validación para ajustar los hiperparámetros.
#
# <font size = 5>6. Evaluación del Modelo </font>
#
# La evaluación es crucial para determinar si el modelo cumple con los objetivos establecidos. Se utilizan métricas específicas según el tipo de problema, como precisión, recall, F1-score para clasificación, o R-squared para regresión.
#
# - Métricas de evaluación: Selección de las métricas adecuadas para el problema.
# - Validación cruzada: Técnica para evaluar el rendimiento del modelo en diferentes conjuntos de datos.
#
# <font size = 5>7. Despliegue </font>
#
# Una vez que el modelo ha sido evaluado y ajustado, se despliega en un entorno de producción. Esto puede implicar integrarlo con aplicaciones existentes o crear una nueva interfaz para que los usuarios interactúen con el modelo.
#
# - Contenerización: Uso de herramientas como Docker para asegurar la consistencia del entorno.
# - APIs: Creación de interfaces de programación de aplicaciones para interactuar con el modelo.
#
# <font size = 5>8. Mantenimiento y Actualización </font>
#
# El mantenimiento es una etapa continua que asegura que el modelo siga siendo relevante y efectivo a lo largo del tiempo. Esto incluye monitorear el rendimiento del modelo, actualizarlo con nuevos datos y ajustar los parámetros según sea necesario.
#
# - Monitoreo del rendimiento: Seguimiento continuo de las métricas de evaluación.
# - Reentrenamiento: Actualización periódica del modelo con nuevos datos para mantener su precisión.
#
# ---
# 🔃Este ciclo de vida es iterativo, y cada etapa puede influir en las demás. Por ejemplo, problemas encontrados durante la evaluación pueden requerir regresar a la etapa de preparación de datos o ingeniería de modelos.

# %% [markdown]
# # 📙 **Bibliografía:**
#
# [historia](https://es.wikipedia.org/wiki/Historia_de_la_inteligencia_artificial)
#
# https://es.wikipedia.org/wiki/Historia_de_la_inteligencia_artificial
#
# https://www.datacamp.com/es/blog/top-ai-bootcamps
#
# https://www.youtube.com/watch?v=mykrieNb9p0
#
# https://www.algotive.ai/es-mx/blog/historia-de-la-inteligencia-artificial-el-machine-learning-y-el-deep-learning
#
# https://adrianvillegasd.com/breve-historia-de-la-evolucion-de-la-inteligencia-artificial/
#
# https://talentotech2.com.co/inteligencia-artificial-explorador/
#
# https://www.ubiqo.net/tecnologia/evolucion-inteligencia-artificial/
#
# https://www.youtube.com/watch?v=2jrG-_gGReY
#
# https://es.weforum.org/stories/2024/10/una-breve-historia-de-la-ia-en-10-momentos-clave/
#
# https://start.docuware.com/es/blog/ia-machine-learning-empresas

# %% [markdown]
# # <font size = 6><center> 🖥️Problemas a Resolver</font></center>
#
# Desarrollaremos un conjunto de script que permitan dar solución a los problemas que a continuación se pleantean.

# %% [markdown]
# ## ✍🏻1. Detección de fiebre
#
# **Contexto:**
#
# Una auxiliar de enfermería debe registrar la temperatura de los pacientes recién ingresados a urgencias.
#
# **Problema:**
#
# Solicita al usuario el nombre y la temperatura de un paciente. Imprime un mensaje indicando si el paciente presenta fiebre (temperatura > 37.5 °C) o no.
#
# **Solución esperada:**
#
# Uso de input(), conversión de tipos (float()), y condicional if.
#
# **Reto**
#
# Permite ingresar la temperatura en Fahrenheit y conviértela a Celsius usando la fórmula:
# <center>
# $C = (F - 32) * \frac{5}{9}$
# </center>
#
# Se debe visualizar el resultado normalizado.

# %%
nombre_paciente = 'Andrés Antonio Gómez García'
temperatura = 38.4

# %%
print(type(nombre_paciente))
print(type(temperatura))
# Out:
# <class 'str'>
# <class 'float'>

# %%
if (temperatura > 37.5):
    print('El paciente tiene fiebre')
else:
    print('El paciente NO tiene fiebre')
# Out:
# Informe:
# El paciente tiene fiebre

# %% [markdown]
# ## ✍🏻2. Clasificación de presión arterial
#
# **Contexto:**
#
# Un hospital necesita clasificar automáticamente la presión arterial sistólica en categorías clínicas.
#
# **Problema:**
#
# Pide al usuario que ingrese un valor de presión sistólica (mmHg) y muestra el diagnóstico correspondiente:
#
# - < 90: Hipotensión
#
# - 90–120: Normal
#
# - 120: Hipertensión
#
# **Solución esperada:**
#
# Condicionales encadenados con if, elif, else.
#
# **Reto:**
#
# Incluye presión diastólica e informa si hay hipertensión tipo 1 según el criterio de la AHA:
#
# ```
# Sistólica ≥ 130 o Diastólica ≥ 80 mmHg.
# ```

# %% [markdown]
# ## ✍🏻3. Registro de paciente con atributos
#
# **Contexto:**
#
# Un sistema de triage rápido debe registrar la edad y sexo de los pacientes.
#
#
# **Problema:**
#
# Solicita nombre, edad y sexo del paciente. Muestra un mensaje como:
#
# *“Paciente Marta, mujer de 65 años, registrada con éxito.”*
#
# **Solución esperada:**
#
# Uso de variables y formato de cadena (f-strings).
#
#
# **Reto:**
#
# Agrega una validación de edad: si es menor de 0 o mayor de 120, muestra un error.

# %% [markdown]
# ## ✍🏻4. Frecuencia cardíaca semanal
#
# **Contexto:**
#
# Una clínica quiere registrar la frecuencia cardíaca en reposo de un paciente durante cinco días consecutivos.
#
# **Problema:**
#
# Solicita cinco valores numéricos y almacénalos en una lista. Calcula el promedio de la frecuencia cardíaca.
#
# **Solución esperada:**
#
# Uso de listas, for, sum(), len().
#
# **Reto:**
#
# Después de calcular el promedio, clasifica el ritmo como:
#
# - < 60: Bradicardia
#
# - 60–100: Normal
#
# - 100: Taquicardia
#
# Presenta un informe.

# %%
# CAPTURA DE DATOS
lista_frecuencias = []
n = 5

for i in range(n):
    frecuencia = int(input('Ingrese el Valor de la Frecuencia: \n'))
    lista_frecuencias.append(frecuencia)

# %%
# CÁLCULO DEL PROMEDIO
sumatoria = 0

for frecuencia in lista_frecuencias:
    sumatoria = sumatoria + frecuencia

cant  = len(lista_frecuencias)
promedio = sumatoria / cant

print(promedio)
# Out:
# 82.8

# %%
# CÁLCULO DEL PROMEDIO opcion 2
sumatoria = sum(lista_frecuencias)
cant = len(lista_frecuencias)
promedio = sumatoria/cant

print(promedio)
# Out:
# 414

# %%
# CÁLCULO DEL PROMEDIO opcion 3
import numpy as np

promedio = np.mean(lista_frecuencias)

print(promedio)
# Out:
# 82.8

# %% [markdown]
# ## ✍🏻5. Análisis de temperaturas clínicas
#
# **Contexto:**
#
# Un epidemiólogo necesita analizar la temperatura diaria de una muestra de 7 pacientes con síntomas febriles.
#
# **Problema:**
#
# Solicita 7 temperaturas y visualiza:
#
# - Temperatura máxima
# - Temperatura mínima
# - Promedio
#
# **Solución esperada:**
#
# Uso de listas y funciones max(), min(), sum().
#
# **Retos:**
#
# - Imprime cuántos pacientes tienen fiebre (> 37.5 °C).
# - Define una temperatura de referencia e informa cuántos superan este valor.

# %%
# EJEMPLO DE SOLUCION - 1

lista = list(map(int, input('Introduce los números de la lista separados por espacio: ').split()))
x = int(input('Introduce el número de referencia (x): '))

# Filtrar y contar valores mayores que x
valores_mayores = [i for i in lista if i > x]
cantidad = len(valores_mayores)

print(f'Hay {cantidad} valores mayores que {x} en la lista.')

# %%
# EJEMPLO DE SOLUCION - 2

import numpy as np

n = 3
lista_temp = []
cont = 0

for i in range(n):
    temp = float(input('Ingrese temperatura\n'))
    lista_temp.append(temp)


maxima = max(lista_temp)
minima = min(lista_temp)
media = np.mean(lista_temp)
cant = len(lista_temp)

for temperatura in lista_temp:
    if temperatura > 37.5:
        cont = cont + 1

print(f'Para {cant} temperaturas, el valor maximo es {maxima} y el mínimo es {minima}, con una media de {media:.2f} y\nla cantidad de registros superiores a 37.5 es de {cont}')
# Out:
# Ingrese temp38
# Ingrese temp37.5
# Ingrese temp36
# Para 3 temperaturas, el valor maximo es 38.0 y el mínimo es 36.0, con una media de 37.166666666666664 y
# la cantidad de registros superiores a 37.5 es de 1

# %% [markdown]
# ## ✍🏻6. Diccionario de pacientes
#
# **Contexto:**
#
# Una sala de consulta debe almacenar y consultar información básica de varios pacientes.
#
# **Problema:**
#
# Crea un diccionario por paciente con los campos: nombre, edad y diagnóstico. Guarda 3 pacientes en una lista. Permite buscar un paciente por nombre e imprime su información.
#
# **Solución esperada:**
#
# Listas de diccionarios, búsqueda lineal.
#
# **Retos:**
#
# - Si el nombre no existe, imprime: “Paciente no encontrado”.
# - Trata de resolverlo usando una lista de diccionarios o un diccionario de diccionarios
#
# *Nota: Considera que los nombres pueden estar escritos con variaciones de mayúsculas y minúsculas*

# %%
# EJEMPLO DE SOLUCION - 1
# Creamos una LISTA que contiene diccionarios, uno por cada paciente

pacientes = [
    {"nombre": "Carlos", "edad": 45, "diagnóstico": "Hipertensión"},
    {"nombre": "María", "edad": 32, "diagnóstico": "Diabetes"},
    {"nombre": "Ana", "edad": 27, "diagnóstico": "Asma"}
]

# Solicitamos al usuario el nombre del paciente a buscar
nombre_buscado = input("Introduce el nombre del paciente que deseas buscar: ")

# Búsqueda lineal del paciente por nombre
paciente_encontrado = None
for paciente in pacientes:
    if paciente["nombre"].lower() == nombre_buscado.lower():
        paciente_encontrado = paciente
        break

# Mostramos la información del paciente o un mensaje si no se encuentra
if paciente_encontrado:
    print(f"\nInformación del paciente:\nNombre: {paciente_encontrado['nombre']}\nEdad: {paciente_encontrado['edad']}\nDiagnóstico: {paciente_encontrado['diagnóstico']}")
else:
    print("Paciente no encontrado.")
# Out:
# Introduce el nombre del paciente que deseas buscar: Carlos
#
# Información del paciente:
# Nombre: Carlos
# Edad: 45
# Diagnóstico: Hipertensión

# %%
# EJEMPLO DE SOLUCION - 2
# Creamos un DICCIONARIO que contiene diccionarios, uno por cada paciente

pacientes = {
    "Carlos": {"edad": 45, "diagnóstico": "Hipertensión"},
    "María": {"edad": 32, "diagnóstico": "Diabetes"},
    "Ana": {"edad": 27, "diagnóstico": "Asma"}
}

# Solicitamos al usuario el nombre del paciente a buscar
nombre_buscado = input("Introduce el nombre del paciente que deseas buscar: ")

# Búsqueda del paciente por nombre (aprovechando la estructura de diccionario)
paciente_encontrado = pacientes.get(nombre_buscado)

# Mostramos la información del paciente o un mensaje si no se encuentra
if paciente_encontrado:
    print(f"\nInformación del paciente:\nNombre: {nombre_buscado}\nEdad: {paciente_encontrado['edad']}\nDiagnóstico: {paciente_encontrado['diagnóstico']}")
else:
    print("Paciente no encontrado.")
# Out:
# Introduce el nombre del paciente que deseas buscar: Carlos
#
# Información del paciente:
# Nombre: Carlos
# Edad: 45
# Diagnóstico: Hipertensión

# %%
pacientes.keys()
# Out:
# dict_keys(['Carlos', 'María', 'Ana'])

# %% [markdown]
# ## ✍🏻PROBLEMA EXTRA - Como importar un csv
#
# En el siguiente ejemplo, tengo un archivo en formato <b>.csv</b> <i>(Comma Separated Values)</i> almacenado en mi computador, con la siguiente estructura pero con un tema distinto propuesto por otro compañero <i>(La profe Yessica)</i>:
#
# | Proveedor | Tipo Tela    | Precio | Descuento |
# |-----------|--------------|--------|-----------|
# | Corbeta   | Lemon Black  | 15900  | 0.10      |
# | Coletex   | Java         | 14900  | 0.08      |
# | Fabricato | Lima         | 16300  | 0.09      |
#
#
# Que se construye asi:
#
#     Proveedor,Tipo Tela,Precio,Descuento
#     Corbeta,Lemon Black,15900,0.1
#     Coletex,Java,14900,0.08
#     Fabricato,Lima,16300,0.09
#
#
# Para poder importar el archivo, se debe acudir al icono de la carpeta 📁 que está en la barra izquierda al final. Luego en el menu que aparece seleccionar el ícono para subir archivo
#
# <img src='https://miro.medium.com/v2/resize:fit:640/format:webp/1*-DnCxq0jtoZnNH4ew6_AZw.png'>
#
# Luego, para acceder a la ubicación del Archivo, vamos a ubicar el puntero del mouse sobre el archivo y cuando aparezcan los 3 puntos <b>⁞</b> seleccionar la opción <b>Copiar ruta</b>

# %%
import csv

# Importar el csv
# 1️⃣Esto crea una LISTA DE DICCIONARIOS
with open('/content/Data_proveedores.csv',
          encoding = 'utf-8') as f:
          datos = list(csv.DictReader(f, delimiter=','))

# %%
# 2️⃣Convertir la Lista de Diccionarios en un DICCIONARIO DE DICCIONARIOS

# Creo el diccionario vacio y en el ciclo lo "alimento" con cada fila o elemento de la lista
proveedores = {}
for fila in datos:
    proveedores[fila['Proveedor']] = fila

# %%
# Imprimir cada elemento (diccionario.... del diccionario proveedores)
# 💡Recordemos que es un diccionario de diccionarios

print('                        Diccionarios en "proveedores"')
for proveedor in proveedores:
    print(proveedores[proveedor])

# Voy a imprimir esta linea para separar las dos impresiones
print('_'*100)

# Imprimir Solo los nombres de los proveedores (que en este caso son las claves)
print('                  Claves en cada diccionario de "proveedores"')
for proveedor in proveedores:
    print(proveedor)
# Out:
#                         Diccionarios en "proveedores"
# {'Proveedor': 'Corbeta', 'Tipo Tela': 'Lemon Black', 'Precio': '15900', 'Descuento': '0.1'}
# {'Proveedor': 'Coletex', 'Tipo Tela': 'Java', 'Precio': '14900', 'Descuento': '0.08'}
# {'Proveedor': 'Fabricato', 'Tipo Tela': 'Lima', 'Precio': '16300', 'Descuento': '0.09'}
# ____________________________________________________________________________________________________
#                   Claves en cada diccionario de "proveedores"
# Corbeta
# Coletex
# Fabricato

# %%
# Ahora podemos buscar en el diccionario usando get y la clave de cada Diccionario

busca_proveedor = input('Nombre del proveedor a buscar: ')
proveedor_encontrado = (proveedores.get(busca_proveedor))

if proveedor_encontrado:
    print(f"Proveedor: {proveedor_encontrado['Proveedor']}")
    print(f"Tipo Tela: {proveedor_encontrado['Tipo Tela']}")
    print(f"Precio: {proveedor_encontrado['Precio']}")
    print(f"Descuento: {proveedor_encontrado['Descuento']}")
    precio_final = float(proveedor_encontrado['Precio']) * (1 - float(proveedor_encontrado['Descuento']))
    print(f"Precio Final: {precio_final}")
else:
    print('No existe')

# %%
# El MISMO Ejemplo, un poco mas largo, pero con el cálculo quizás mas claro

busca_proveedor = input('Nombre del proveedor a buscar: ')
proveedor_encontrado = (proveedores.get(busca_proveedor))

if proveedor_encontrado:
    print(f"Proveedor: {proveedor_encontrado['Proveedor']}")
    print(f"Tipo Tela: {proveedor_encontrado['Tipo Tela']}")
    print(f"Precio: {proveedor_encontrado['Precio']}")
    print(f"Descuento: {proveedor_encontrado['Descuento']}")

    # Traigo a variables el contenido de Precio y Descuento del Diccionario
    precio = float(proveedor_encontrado['Precio'])
    descuento = float(proveedor_encontrado['Descuento'])

    # Calculo el Precio Final e imprimo
    precio_final = precio * (1 - descuento)

    print(f"Precio Final: {precio_final}")
else:
    print('No existe')

# %% [markdown]
# ## ✍🏻7. Reporte automático de paciente
#
# **Contexto:**
#
# Se requiere generar un resumen automático del estado general de un paciente.
#
# **Problema:**
#
# Dado un diccionario con 'nombre', 'edad', 'temperatura' y 'presión', muestra un resumen en una sola línea.
#
# **Solución esperada:**
#
# Acceso a valores de diccionario y presentación con print().
#
# **Reto:**
#
# Agrega una alerta si la temperatura > 38 o la presión > 140.

# %%
# Diccionario inicial de pacientes
pacientes = {
    "Carlos": {"edad": 45, "diagnóstico": "Hipertensión"},
    "María": {"edad": 32, "diagnóstico": "Diabetes"},
    "Ana": {"edad": 27, "diagnóstico": "Asma"}
}

# Mostrar el resumen del estado general de cada paciente
for nombre, datos in pacientes.items():
    resumen = f"Paciente {nombre}, {datos['edad']} años, diagnóstico: {datos['diagnóstico']}."
    print(resumen)
# Out:
# Paciente Carlos, 45 años, diagnóstico: Hipertensión.
# Paciente María, 32 años, diagnóstico: Diabetes.
# Paciente Ana, 27 años, diagnóstico: Asma.

# %% [markdown]
# ## ✍🏻8. Filtrado de riesgo cardiovascular
#
# **Contexto:**
#
# Una investigación busca identificar pacientes con riesgo cardiovascular.
#
# **Problema:**
#
# Dado un listado de pacientes (cada uno como diccionario), muestra solo los nombres de quienes tienen edad > 60 y presión > 140.
#
# **Solución esperada:**
#
# Iteración con for, condicional múltiple (and).
#
# **Reto:**
#
# Cuenta cuántos pacientes cumplen el criterio de riesgo.

# %%
# Diccionario de pacientes
pacientes = {
    "Carlos": {"edad": 65, "presión": 150},
    "María": {"edad": 58, "presión": 130},
    "Ana": {"edad": 70, "presión": 145},
    "Juan": {"edad": 75, "presión": 160}
}

# Lista para almacenar los pacientes que cumplen las condiciones
pacientes_filtrados = {}

# Iteramos sobre cada paciente
for nombre, datos in pacientes.items():
    if datos["edad"] > 60 and datos["presión"] > 140:
        pacientes_filtrados[nombre] = datos

# Mostrar los pacientes filtrados con nombres y datos
print("Pacientes mayores de 60 años con presión superior a 140:")
for nombre, datos in pacientes_filtrados.items():
    print(f"{nombre}: Edad - {datos['edad']}, Presión - {datos['presión']}")

# %% [markdown]
# ## 🧠 <b>PROBLEMA EXTRA: Evaluación de la tasa de deterioro cognitivo</b>
#
# **Contexto**
#
# <font size = 3>Un grupo de investigadores quiere estudiar la progresión del deterioro cognitivo en pacientes con Alzheimer. Para esto, se usa el puntaje MMSE *(Mini-Mental State Examination)*, una prueba que evalúa el estado cognitivo general del paciente. Se plantea relacionar este puntaje con el tiempo transcurrido desde el diagnóstico de la enfermedad.
# <br><br>
#
# <font size = 3>**Columnas del archivo .csv**
#
# | **Variable**                  | **Tipo de dato** | **Descripción**                                                             |
# |------------------------------|------------------|------------------------------------------------------------------------------|
# | `ID_Paciente`                | string           | Identificador único                                                         |
# | `Edad`                       | entero           | Edad del paciente                                                           |
# | `MMSE`                       | entero           | Puntuación del *Mini-Mental State Examination* (0–30)                       |
# | `MoCA`                       | entero           | Puntuación del *Montreal Cognitive Assessment* (0–30)                       |
# | `Volumen_Hipocampo`         | flotante         | Medido por neuroimagen (cm³ o mm³)                                          |
# | `Años_Diagnóstico`          | entero           | Tiempo desde el diagnóstico                                                 |
# | `Nivel_Actividad_Física`    | flotante         | Horas semanales de actividad física                                         |
# | `Índice_Masa_Corporal`      | flotante         | BMI del paciente                                                            |
# | `Porcentaje_Pérdida_Memoria`| flotante         | Estimación autoinformada o médica del deterioro (0–100%)                   |
#
# <br>
#
# <font size = 4>**Problema**
#
# <font size = 3>Cada paciente tiene una puntuación MMSE y un valor que indica cuántos años han pasado desde su diagnóstico. Se desea calcular una nueva medida llamada **Tasa de Deterioro Cognitivo**, que se define como el <font color = #2C7194>**cociente entre el puntaje MMSE y los años desde el diagnóstico**.</font>
#
# <font size = 3>Sin embargo, hay pacientes que apenas han sido diagnosticados (0 años), por lo que en estos casos la tasa se definirá como igual al valor MMSE (para evitar divisiones por cero).
#
# <font size = 4>**Solución esperada**
#
# <font size = 3>El estudiante debe imprimir esta  **'Tasa de Deterioro Cognitivo'**. Para cada paciente, esta tasa debe calcularse <font color = #2C7194>dividiendo su puntaje MMSE entre el número de años desde el diagnóstico.</font>
#
# <font size = 3>En los casos donde el número de años sea igual a cero, se debe asignar directamente el valor de MMSE como tasa.
#
# <font size = 3>El resultado debe ser mostrado para cada paciente, indicando su ID, puntaje MMSE, años desde el diagnóstico y la tasa calculada, con un formato claro y legible.
#
# <font size = 4>**Retos**
# <font size = 3>
# - <font size = 3>Contar cuántos pacientes tienen una tasa de deterioro menor a 2.0.
# - <font size = 3>Calcular el promedio general de la tasa de deterioro en toda la muestra.
# - <font size = 3>Crear un nuevo diccionario con los pacientes que tienen tasas bajas y podrían considerarse en riesgo alto de deterioro. *(Esto veremos hacerlo después* 😉*)*

# %%
import csv
import urllib.request

# URL del dataset
url = 'https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/pacientes_alzheimer_datos_sinteticos.csv'

# Descargar y leer el archivo CSV como lista de diccionarios
response = urllib.request.urlopen(url)

# Leer las lineas del archivo y decodificar los bytes a texto (UTF-8)
lines = [l.decode('utf-8') for l in response.readlines()]

# Convertir el contenido de la lista (archivo csv) en una lista de diccionarios
data = list(csv.DictReader(lines))

data
# Out:
# [{'ID_Paciente': 'P0001',
#   'Edad': '66',
#   'MMSE': '24',
#   'MoCA': '27',
#   'Volumen_Hipocampo': '3.83',
#   'Annos_Diagnostico': '0',
#   'Nivel_Actividad_Fisica': '4.9',
#   'Indice_Masa_Corporal': '26.4',
#   'Porcentaje_Perdida_Memoria': '42.0'},
#  {'ID_Paciente': 'P0002',
#   'Edad': '79',
#   'MMSE': '28',
#   'MoCA': '30',
#   'Volumen_Hipocampo': '3.62',
#   'Annos_Diagnostico': '15',
#   'Nivel_Actividad_Fisica': '1.0',
#   'Indice_Masa_Corporal': '24.6',
#   'Porcentaje_Perdida_Memoria': '59.3'},
#  {'ID_Paciente': 'P0003',
#   'Edad': '88',
#   'MMSE': '18',
#   'MoCA': '18',
#   'Volumen_Hipocampo': '3.88',
#   'Annos_Diagnostico': '2',
#   'Nivel_Actividad_Fisica': '0.9',
#   'Indice_Masa_Corporal': '23.1',
#   'Porcentaje_Perdida_Memoria': '29.4'},
#  {'ID_Paciente': 'P0004',
#   'Edad': '74',
#   'MMSE': '28',
#   'MoCA': '28',
#   'Volumen_Hipocampo': '3.98',
#   'Annos_Diagnostico': '15',
#   'Nivel_Actividad_Fisica': '6.8',
# ...

# %%
pacientes = {}
for row in data:
    pacientes[row['ID_Paciente']] = row

pacientes
# Out:
# {'P0001': {'ID_Paciente': 'P0001',
#   'Edad': '66',
#   'MMSE': '24',
#   'MoCA': '27',
#   'Volumen_Hipocampo': '3.83',
#   'Annos_Diagnostico': '0',
#   'Nivel_Actividad_Fisica': '4.9',
#   'Indice_Masa_Corporal': '26.4',
#   'Porcentaje_Perdida_Memoria': '42.0'},
#  'P0002': {'ID_Paciente': 'P0002',
#   'Edad': '79',
#   'MMSE': '28',
#   'MoCA': '30',
#   'Volumen_Hipocampo': '3.62',
#   'Annos_Diagnostico': '15',
#   'Nivel_Actividad_Fisica': '1.0',
#   'Indice_Masa_Corporal': '24.6',
#   'Porcentaje_Perdida_Memoria': '59.3'},
#  'P0003': {'ID_Paciente': 'P0003',
#   'Edad': '88',
#   'MMSE': '18',
#   'MoCA': '18',
#   'Volumen_Hipocampo': '3.88',
#   'Annos_Diagnostico': '2',
#   'Nivel_Actividad_Fisica': '0.9',
#   'Indice_Masa_Corporal': '23.1',
#   'Porcentaje_Perdida_Memoria': '29.4'},
#  'P0004': {'ID_Paciente': 'P0004',
#   'Edad': '74',
#   'MMSE': '28',
#   'MoCA': '28',
#   'Volumen_Hipocampo': '3.98',
#   'Annos_Diagnostico': '15',
# ...

# %%
# Calcular y mostrar la Tasa de Deterioro Cognitivo
for cada_paciente in pacientes:
    paciente = pacientes[cada_paciente]

    mmse = float(paciente['MMSE'])
    annos = int(paciente['Annos_Diagnostico'])

    if annos ==  0:
        tasa = round(mmse, 2)
    else:
        tasa = round(mmse / annos, 2)

    paciente['Tasa_Deterioro'] = tasa

    print(f'Paciente {cada_paciente} → MMSE: {mmse}, Años Dx: {annos}, Tasa: {tasa}')

# %% [markdown]
# ## ✍🏻9. Etiquetado de riesgo
#
# **Contexto:**
#
# Se necesita generar etiquetas de riesgo a partir de variables básicas.
#
# **Problema:**
#
# Pide al usuario edad y temperatura. Si edad > 65 y temperatura > 38.0, muestra "ALTO RIESGO", si no, muestra "RIESGO CONTROLADO".
#
# **Solución esperada:**
#
# Condicional anidado con operador and.
#
# **Reto:**
#
# Devuelve las etiquetas como parte de un diccionario para posible reutilización posterior.

# %%
import csv
import urllib.request
cont = 0

# URL del dataset
url = 'https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/Etiquetado_Riesgo.csv'

# Descargar y leer el archivo CSV como lista de diccionarios
response = urllib.request.urlopen(url)

# Leer las lineas del archivo y decodificar los bytes a texto (UTF-8)
lines = [l.decode('utf-8-sig') for l in response.readlines()]

# Convertir el contenido de la lista (archivo csv) en una lista de diccionarios
data = list(csv.DictReader(lines))

pacientes = {}                  # Con esto creo un diccionario VACÍO

for row in data:                # Recorro la data fila(row) por fila(row)
    pacientes[row['ID']] = row  # al diccionario en la Posición(fila) le llevo la fila entera

print(' '*30,'INFORME')
print('▪'*65)
# Calcular y mostrar la Etiqueta de RIESGO
for cada_paciente in pacientes:
    paciente = pacientes[cada_paciente]

    edad = int(paciente['Edad'])
    temperatura = float(paciente['Temperatura'])

    if edad > 65 and temperatura > 38:
        etiqueta = "ALTO RIESGO"
        cont = cont + 1
    else:
        etiqueta = "RIESGO CONTROLADO"

    paciente['Etiqueta'] = etiqueta

    print(f'Paciente {cada_paciente}, Edad {edad}, Temperatura {temperatura}°C → \t{etiqueta}')

print(f'La cantidad de Pacientes con ALTO RIESGO son {cont}')

# %% [markdown]
# ## ✍🏻10. Ingreso múltiple de pacientes
#
# **Contexto:**
#
# Una aplicación médica debe permitir ingresar múltiples pacientes.
#
# **Problema:**
#
# Permite ingresar pacientes (nombre y temperatura) en un ciclo while. Finaliza cuando el usuario escribe 'salir'. Muestra todos los pacientes ingresados.
#
# **Solución esperada:**
#
# Ciclo while, control de flujo con break, acumulación en listas.
#
# **Reto:**
#
# Después de mostrar la lista, indica cuántos presentaron fiebre (> 37.5 °C).

# %% [markdown]
# # 🛠️ FUNCIONES
#
# <font size = 4>📌 **¿Qué es una función?**
#
# Imagina que una función es como un protocolo clínico estandarizado. En lugar de repetir los mismos pasos cada vez (como diagnosticar una gripe), defines el protocolo una vez y luego solo lo aplicas cuando lo necesitas, cambiando los datos del paciente.
#
# <font size = 4>💡 **¿Para qué sirven?**
# - Evitar repeticiones: No escribes 100 veces los mismos pasos (¡como recetar paracetamol manualmente a cada paciente!).
# - Organizar el código: Tus scripts son como historias clínicas bien estructuradas, no notas desordenadas.
# - Reutilizar: Puedes usar la función en muchos proyectos (como un protocolo aplicable en varios hospitales).
#
# <font size = 4>📢 **Frase clave para recordar:**
# "Una función es un protocolo reutilizable que transforma datos (input) en resultados (output), sin repetir pasos."

# %%
data = [
    ['Juan', 36.5],
    ['María', 37.2],
    ['Luis', 36.8],
    ['Ana', 38.1],
    ['Carlos', 36.4],
    ['Sofía', 37.0],
    ['Andrés', 36.9],
    ['Paula', 36.7],
    ['José', 37.5],
    ['Laura', 36.6],
    ['Mateo', 36.2],
    ['Isabela', 37.8],
    ['Miguel', 36.1],
    ['Valentina', 36.3],
    ['Daniel', 37.3],
    ['Camila', 36.0],
    ['Felipe', 37.1],
    ['Manuela', 36.5],
    ['Sebastián', 38.0],
    ['Juliana', 36.4],
    ['David', 36.8],
    ['Gabriela', 37.4],
    ['Santiago', 36.6],
    ['Natalia', 37.6],
    ['Tomás', 36.7],
    ['Luciana', 37.2],
    ['Samuel', 36.9],
    ['Sara', 37.0],
    ['Emilio', 36.5],
    ['Daniela', 37.7]
]

# DEFINIMOS LA FUNCIÓN QUE RECIBE EL ARGUMENTO -Temperatura-
def Interpreta_Temp(temperatura):
    if temperatura >= 38:
        resultado = 'Fiebre'
    elif temperatura >= 36:
        resultado = 'Normal'
    else:
        resultado = 'Hipotermia'

    return resultado

# CAPTURAMOS EL DATO
temp = float(input('Ingrese el valor de la Temperatura: '))

# INVOCAMOS LA FUNCIÓN, ENVIANDO EL PARÁMETRO -temp-
res = Interpreta_Temp(temp)
# Y RECIBIMOS EL RETURN (resultado) EN LA VARIABLE -res-

print(f'El resultado de la medición es: {res}')

# %% [markdown]
# # 🐼 PANDAS
#
# <font size = 4>**¿Qué es Pandas?**
#
# Es una libreta de notas inteligente para organizar y analizar datos. Imagínalo como el Excel de Python, pero más potente.
#
# <font size = 4>🏥 **Analogía Médica**
#
# Tus datos clínicos (columnas = variables, filas = pacientes):
#
#
#
# ```python
# import pandas as pd
#
# dicc_pacientes = {
#     'Paciente': ['Ana', 'Luis', 'Sofía'],
#     'Edad': [45, 60, 38],
#     'Glucosa': [120, 98, 150],  # mg/dL
#     'Fumador': ['No', 'Sí', 'No']
# }
#
# # Crear un "DataFrame" con el diccionario
# df = pd.DataFrame(dicc_pacientes)
#
# print(df)
#
# ```
# **Salida:**
#
# | <font size = 3>Paciente | <font size = 3>Edad | <font size = 3>Glucosa | <font size = 3>Fumador |
# |----------|------|---------|---------|
# | <font size = 3>Ana      |  <font size = 3>45  |   <font size = 3>120   |   <font size = 3>No    |
# | <font size = 3>Luis     |  <font size = 3>60  |    <font size = 3>98   |   <font size = 3>Sí    |
# | <font size = 3>Sofía    |  <font size = 3>38  |   <font size = 3>150   |   <font size = 3>No    |
# <br>
#
# <font size = 4>📌 **Clave para Recordar**
#
# - DataFrame = Tu tabla de pacientes.
# - Columnas = Variables clínicas.
# - Filas = Pacientes individuales.
#
# <i>"Pandas es como el sistema de historiales clínicos de Python: te deja ordenar, filtrar y analizar datos masivos en segundos"

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/pacientes_alzheimer_datos_sinteticos.csv'


df = pd.read_csv(url)

df.info()

# %% [markdown]
# <center><img src = 'https://github.com/juliandariogiraldoocampo/ia_taltech/blob/main/Inteligencia_Artificial.png?raw=true'></center>

# %% [markdown]
# # <font size = 6>📚 Recolección de Datos

# %% [markdown]
# ## **1. Fuentes de Datos**
#
# Definición: Son los orígenes desde donde se obtiene la información que usaremos en nuestros proyectos de IA.
#
# Ejemplos:
#
# * Datasets abiertos (e.g., Kaggle, UCI Machine Learning Repository).
# * APIs públicas (e.g., APIs hospitalarias, openFDA).
# * Registros clínicos electrónicos (EHR).
# * Sensores biométricos o dispositivos médicos.
# * Bases de datos institucionales.

# %% [markdown]
# ## **2. Ejemplos de Conjuntos de Datos Disponibles**
#
# * Kaggle:
#     * Alzheimer's Disease Progression Prediction.
#     * Diabetic Retinopathy Detection.
#     * Heart Disease UCI.
# * Google Dataset Search.
# * UCI Machine Learning Repository.
# * World Health Organization Open Data.
# * Ejemplo práctico en esta sesión:
#
# 📄 Trabajaremos con el dataset:
# https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/pacientes_alzheimer_datos_sinteticos.csv

# %% [markdown]
# ## **3. Tipos de Bases de Datos**
#
# **Bases de Datos Relacionales:**
#
# - MySQL, PostgreSQL.
# - Organizadas en tablas con relaciones definidas.
#
# **Bases de Datos No Relacionales:**
#
# - MongoDB, Firebase.
# - Útiles para datos semi-estructurados o sin estructura (imágenes, textos).

# %% [markdown]
# ## **4. Carga de Datos**
#
# Ejemplo de carga del dataset en Python:

# %%
import pandas as pd

# URL del dataset
url = 'https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/pacientes_alzheimer_datos_sinteticos.csv'

# Cargar datos
df = pd.read_csv(url)

print(df.head())
df.head()
# Out:
#   ID_Paciente  Edad  MMSE  MoCA  Volumen_Hipocampo  Annos_Diagnostico  \
# 0       P0001    66    24    27               3.83                  0
# 1       P0002    79    28    30               3.62                 15
# 2       P0003    88    18    18               3.88                  2
# 3       P0004    74    28    28               3.98                 15
# 4       P0005    70    29    19               2.70                  1
#
#    Nivel_Actividad_Fisica  Indice_Masa_Corporal  Porcentaje_Perdida_Memoria
# 0                     4.9                  26.4                        42.0
# 1                     1.0                  24.6                        59.3
# 2                     0.9                  23.1                        29.4
# 3                     6.8                  19.7                        17.0
# 4                     5.0                  18.9                        11.9
#   ID_Paciente  Edad  MMSE  MoCA  Volumen_Hipocampo  Annos_Diagnostico  \
# ...

# %% [markdown]
# ## **5. Generación de Datos Sintéticos**
#
# **Definición:** Crear datos artificiales que imitan patrones de los datos reales.
#
# **¿Cómo podría ser útil en el área de la salud?**
#
# - Privacidad de pacientes.
# - Aumentar el tamaño de los datasets (data augmentation).
#
# **Métodos:**
#
# - Generadores simples (numpy, scikit-learn).
# - Técnicas avanzadas: GANs (Generative Adversarial Networks).

# %%
import numpy as np
import pandas as pd

# Configurar semilla para reproductibilidad
np.random.seed(42)

# Generar datos sintéticos de edad y puntaje de memoria
edad = np.random.normal(70, 8, 100)
memoria = np.random.normal(25, 5, 100)


df_sintetico = pd.DataFrame({
    'Edad': edad,
    'Puntaje_memoria': memoria
})

df_sintetico.head()
# Out:
#         Edad  Puntaje_memoria
# 0  73.973713        17.923146
# 1  68.893886        22.896773
# 2  75.181508        23.286427
# 3  82.184239        20.988614
# 4  68.126773        24.193571

# %%
import numpy as np
import pandas as pd

# Configurar semilla para reproductibilidad
np.random.seed(42)

# Definir número de observaciones (registros)
n = 16
opciones = ["Masculino", "Femenino"]
prob = [0.5, 0.5]

# Generar datos sintéticos de edad y puntaje de memoria
edad = np.random.normal(70, 8, n)
memoria = np.random.normal(25, 5, n)

# Generar datos sintéticos de género con Probabilidad 50% cada uno
genero = np.random.choice(opciones, size=n, p=prob)

df_sintetico = pd.DataFrame({
    'Edad': edad,
    'Puntaje_memoria': memoria,
    'Género': genero
})

df_sintetico

# %% [markdown]
# <font size = 5>💡Generar columnas relacionadas:
# Si el género afecta el puntaje de memoria, puedes añadir lógica condicional:

# %%
import numpy as np
import pandas as pd

# Configurar semilla para reproductibilidad
np.random.seed(42)

# Inicializar Variables
n = 100                             # Número de Observaciones/registros
opciones = ["Masculino", "Femenino"]
prob =  [0.5, 0.5]                  # Probabilidad de cada opción. ejemplo 50%-50%

# Generar datos sintéticos de edad
edad = np.random.normal(70, 8, n)   # Media, Desv.Estándar, Número de Observaciones

# Generar datos sintéticos de género
genero = np.random.choice(opciones, size=n, p=prob)

# Si el género afecta el puntaje de memoria
memoria = np.where(genero == "Masculino",      # Condición
                  np.random.normal(26, 5, n),  # Si... Hombres con media 26
                  np.random.normal(24, 5, n))  # Sino... Mujeres con media 24

# Crear el Dataframe con las listas
df_sintetico = pd.DataFrame({
    'Edad': edad,
    'Puntaje_memoria': memoria,
    'Género': genero
})

df_sintetico.head()

# %% [markdown]
# <font size=5>📢 Claves para usar np.random:
#
# <font size=4>**Distribución simétrica:**
# La mayoría de los datos se concentran cerca de la media, y los extremos son menos probables.
#
# <font size=4>**Uso típico:**
# Modelar características como alturas, puntajes de tests, errores de medición, etc.
#
# <font size=4>**¿Por qué no usar `np.random.rand()`?**
#
# <font size=4>`rand()` genera datos uniformes (todos los valores tienen igual probabilidad), mientras que `normal()` refleja fenómenos reales donde los valores centrales son más comunes.

# %% [markdown]
# ## **6. Calidad y Cantidad de Datos**
#
# **Calidad de Datos:**
# - Completitud: ¿Faltan datos?
# - Consistencia: ¿Hay contradicciones?
# - Exactitud: ¿Reflejan la realidad?
# - Actualidad: ¿Son datos recientes?
#
# **Cantidad de Datos:**
# - Modelos de IA robustos requieren suficientes datos para generalizar.
# - Técnicas como transferencia de aprendizaje pueden ayudar cuando los datos son escasos.

# %%
df.shape
# Out:
# (100, 9)

# %%
# Evaluar cantidad de datos
print(f'Registros: {df.shape[0]}, Variables: {df.shape[1]}')
# Out:
# Registros: 100, Variables: 9

# %%
# Evaluar valores faltantes
df.isnull().sum()
# Out:
# ID_Paciente                   0
# Edad                          0
# MMSE                          0
# MoCA                          0
# Volumen_Hipocampo             0
# Annos_Diagnostico             0
# Nivel_Actividad_Fisica        0
# Indice_Masa_Corporal          0
# Porcentaje_Perdida_Memoria    0
# dtype: int64

# %%
# Estadísticas descriptivas
df.describe()
# Out:
#              Edad        MMSE        MoCA  Volumen_Hipocampo  \
# count  100.000000  100.000000  100.000000         100.000000
# mean    75.630000   22.940000   22.350000           3.901000
# std      9.033781    4.509967    4.738356           0.688247
# min     60.000000   15.000000   15.000000           2.550000
# 25%     67.000000   19.000000   18.000000           3.325000
# 50%     77.000000   23.000000   23.000000           3.870000
# 75%     84.000000   27.000000   26.000000           4.512500
# max     89.000000   30.000000   30.000000           4.990000
#
#        Annos_Diagnostico  Nivel_Actividad_Fisica  Indice_Masa_Corporal  \
# count         100.000000               100.00000             100.00000
# mean            7.760000                 3.41200              26.70500
# std             4.671253                 1.99956               4.96949
# min             0.000000                 0.10000              18.50000
# ...

# %% [markdown]
# # <font size = 6> 🎨 Visualización de Datos

# %% [markdown]
# ## **1. Importancia de la Visualización de Datos**
#
# - Permite identificar patrones, tendencias y anomalías.
# - Facilita la interpretación de los datos antes de construir modelos predictivos.
# - Ayuda a detectar errores en los datos (outliers, datos mal cargados).

# %% [markdown]
# ## **2. Tipos de Gráficos**

# %% [markdown]
# ## **📊 2.1 Histogramas**
#
# **Objetivo:**
#
# - Mostrar la distribución de una variable continua.
# - Permite observar la frecuencia de ocurrencia de los valores.
#
# **¿Cuándo usarlo?**
#
# - Para ver la forma general de la distribución (normal, sesgada, etc.).
# - Para identificar la presencia de valores extremos.

# %%
import matplotlib.pyplot as plt

plt.hist(df['Edad'],
         bins=20)

plt.show()

# %%
import matplotlib.pyplot as plt

# Histograma de la variable 'Edad' con matplotlib
plt.figure(figsize=(8, 5))

plt.hist(df['Edad'],
         bins=20,
         color='skyblue',
         edgecolor='black')

plt.title('Distribución de la Edad', fontsize=14)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.grid(axis='y', alpha=0.3)

plt.show()

# %% [markdown]
# ## 📦 2.2 Diagramas de Caja (Boxplots)
#
# **Objetivo:**
# - Mostrar la mediana, cuartiles y valores atípicos (outliers) de una variable.
#
# **¿Cuándo usarlo?**
# - Para comparar distribuciones entre grupos.
# - Para detectar valores extremos que podrían afectar el modelo.
#
# **Partes del Boxplot:**
# - Caja: Representa el rango intercuartílico (IQR).
# - Línea dentro de la caja: Mediana.
# - Bigotes: Extensión de los datos sin considerar outliers.
# - Puntos fuera de los bigotes: Outliers.

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.boxplot(x=df['Volumen_Hipocampo'], color='lightgreen')
plt.title('Diagrama de Caja del Volumen del Hipocampo')
plt.xlabel('Puntaje MMSE')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionamos las columnas que queremos visualizar
variables = ['MMSE', 'MoCA', 'Volumen_Hipocampo']

# Creamos un DataFrame reducido solo con esas variables
df_box = df[variables]

# Configuración de la figura
plt.figure(figsize=(10,6))

# Creamos el boxplot múltiple
sns.boxplot(data=df_box, palette='Set2')

# Títulos y etiquetas
plt.title('Diagramas de Caja de MMSE, MoCA y Volumen del Hipocampo')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# hacer boxplots por grupos (por ejemplo, comparar las edades entre pacientes con mayor o menor años de Diagnóstico).
#
# Pero eso implicaría usar la opción x para categorías.

# %%
sns.boxplot(x='Annos_Diagnostico', y='Edad', data=df)

# %% [markdown]
# ## 🌊 2.3 Gráficos de Densidad
#
# **Objetivo:**
# - Mostrar una estimación suave de la distribución de una variable continua.
# - Similar a un histograma pero más "suave" y continuo.
#
# **¿Cuándo usarlo?**
# - Cuando se quiere visualizar mejor la forma de la distribución (especialmente en datos clínicos).
# - Para comparar múltiples distribuciones en un mismo gráfico.

# %%
# Gráfico de densidad para 'Edad'
plt.figure(figsize=(8,5))
sns.kdeplot(df['Edad'], shade=True, color='salmon')
plt.title('Densidad de la Edad')
plt.xlabel('Edad')
plt.ylabel('Densidad')
plt.show()
# Out:
# <ipython-input-55-45ef835f048e>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Edad'], shade=True, color='salmon')

# %% [markdown]
# <font size = 5>Gráfico de densidad o KDE plot (Kernel Density Estimate) de la variable 'Edad'.
#
# **1. ¿Qué representa?**
#
# -** Eje X:** Representa las edades de los pacientes (desde aproximadamente 50 hasta casi 100 años).
# - **Eje Y:** Representa la densidad de probabilidad. <u>No es un número de pacientes, sino **una medida proporcional que muestra dónde se concentran más los datos**</u>.
#
# Una mayor altura en la curva indica mayor concentración de pacientes en ese rango de edad.
#
# **2. Interpretación visual**
# - **Entre 60 y 70 años:**
# Hay una primera subida: muchos pacientes están en ese rango de edad (por ejemplo, entre 65 y 70 años).
#
# - **Entre 70 y 80 años:**
# Hay una pequeña disminución, pero sigue habiendo una densidad moderada.
#
# - **Cerca de 80 años:**
# Hay otra subida importante. Esto indica que otra gran cantidad de pacientes tiene entre 75 y 85 años.
#
# - **A partir de 90 años:**
# La densidad cae rápidamente: hay muy pocos pacientes mayores de 90 años.

# %% [markdown]
# ## 🔬 Comparación de densidades: Edad según pérdida de memoria
# 🎯 Objetivo
# Visualizar cómo varía la edad de los pacientes según el porcentaje de pérdida de memoria:
#
# ¿Son los pacientes con mayor pérdida de memoria más longevos?
#
# ¿Existe una diferencia clara en la distribución de edad entre ambos grupos?

# %% [markdown]
# ### 🛠️ Paso 1: Crear una columna categórica
#
# Clasificamos a los pacientes en dos grupos según su pérdida de memoria:

# %%
# Carguemos de nuevo los datos en caso de que ya se haya reiniciado Sesión
import pandas as pd

# URL del dataset
url = 'https://raw.githubusercontent.com/juliandariogiraldoocampo/ia_taltech/refs/heads/main/pacientes_alzheimer_datos_sinteticos.csv'

# Cargar datos
df = pd.read_csv(url)

# %%
# Crear columna categórica
import numpy as np

df['Grupo_Memoria'] = np.where(df['Porcentaje_Perdida_Memoria'] >= 40, 'Alta Pérdida', 'Baja Pérdida')

# %% [markdown]
# ### 📈 Paso 2: Gráfico de densidad comparativo

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer estilo de seaborn
sns.set_style('whitegrid')

plt.figure(figsize=(8,4))

# Configuración personalizada de colores
paleta_perd_mem = {
    'Alta Pérdida': '#D55E00',
    'Baja Pérdida': '#0072B2'
}

sns.kdeplot(
    data=df,
    x='Edad',
    hue='Grupo_Memoria',
    fill=True,
    alpha=0.4,
    linewidth=1,
    palette = paleta_perd_mem,
    common_norm=False # NO Normalizamos → Distribución de cada grupo de forma independiente
)

plt.title('Distribución de Edad por Pérdida de Memoria \n→ DISTRIBUCIÓN en cada Grupo ←')
plt.ylabel('Densidad')
plt.xlabel('Edad')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer estilo de seaborn https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.set_style('whitegrid')

plt.figure(figsize=(8,4))

# Configuración personalizada de colores
paleta_perd_mem = {
    'Alta Pérdida': '#D55E00',
    'Baja Pérdida': '#0072B2'
}

sns.kdeplot(
    data=df,
    x='Edad',
    hue='Grupo_Memoria',
    fill=True,
    alpha=0.4,
    linewidth=1,
    palette = paleta_perd_mem,
    common_norm=True, # Normalizamos ambas curvas → Proporción de cada Curva en el total
)

plt.title('Distribución de Edad por Pérdida de Memoria \n→ PROPORCIÓN de cada Grupo ←')
plt.ylabel('Densidad')
plt.xlabel('Edad')

plt.show()

# %% [markdown]
# # <font size = 6>🔍 Análisis Exploratorio de Datos (EDA)</font>
#
# <font size = 5>🎯 Objetivo del EDA</font>
#
# <font size = 4>Explorar y resumir las características principales de un conjunto de datos antes de aplicar modelos de aprendizaje automático. Permite:
#
# - <font size = 4>Identificar patrones.
# - <font size = 4>Detectar errores.
# - <font size = 4>Formular hipótesis.
# - <font size = 4>Elegir variables relevantes.

# %% [markdown]
# ## **<font size = 5>✅ Reto 1: Exploración de Datos Médicos**
#
# Dimensiones de la Calidad de Datos** ✦ Completitud, Consistencia, Exactitud

# %%
import pandas as pd

# Carga de los Datos
url = 'https://github.com/juliandariogiraldoocampo/ia_taltech/raw/refs/heads/main/Dataset%201%20_%20Pima%20Indians%20diabetes%20dataset%20(PIDD)_modificado.xlsx'

# Cargar la hoja sin asumir encabezados
df_raw = pd.read_excel(url, header=None) # En caso de no querer cargar los encabezados del archivo

# %%
# Evaluar cantidad de datos
print(f'Registros/Observaciones: {df_raw.shape[0]}, Variables: {df_raw.shape[1]}')
# Out:
# Registros/Observaciones: 777, Variables: 10

# %%
# Completitud: detectar valores ausentes
print(df_raw.isnull().sum())
# Out:
# 0    777
# 1      5
# 2      8
# 3     11
# 4     10
# 5     10
# 6     10
# 7     14
# 8     11
# 9      8
# dtype: int64

# %%
# Consistencia: verificar tipos de datos y valores esperados
print(df_raw.dtypes)
# Out:
# 0    float64
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# dtype: object

# %%
# Exactitud (básica): verificar si los valores están dentro de rangos esperados
print(df_raw.describe())
# Out:
#          0
# count  0.0
# mean   NaN
# std    NaN
# min    NaN
# 25%    NaN
# 50%    NaN
# 75%    NaN
# max    NaN

# %% [markdown]
# ## **<font size = 5>✅ Reto 2. Limpieza y Preparación de Datos *(Hands-on)***

# %%
print('Primeras Filas')
print(df_raw.head(5))
print('_'*80)
print('Últimas Filas')
print(df_raw.tail(5))
# Out:
# Primeras Filas
#     0                                                  1    2    3  \
# 0 NaN                                                NaN  NaN  NaN
# 1 NaN                                                NaN  NaN  NaN
# 2 NaN  Published: 15 August 2022 | Version 1 | DOI: 1...  NaN  NaN
# 3 NaN  Description\nThese datasets were used to devel...  NaN  NaN
# 4 NaN                                                NaN  NaN  NaN
#
#                    4    5    6    7    8    9
# 0                NaN  NaN  NaN  NaN  NaN  NaN
# 1  Diabetes Datasets  NaN  NaN  NaN  NaN  NaN
# 2                NaN  NaN  NaN  NaN  NaN  NaN
# 3                NaN  NaN  NaN  NaN  NaN  NaN
# 4                NaN  NaN  NaN  NaN  NaN  NaN
# ________________________________________________________________________________
# Últimas Filas
#       0                                                  1    2    3    4  \
# 772 NaN                                                  1  126   60    0
# ...

# %% [markdown]
# <font size = 4>**✂️ Extracción de la tabla útil**
#
# Cuando identifiquemos dónde comienza la tabla útil y los encabezados reales, extraemos los datos como un nuevo DataFrame.

# %%
df_raw.head(10)
# Out:
#     0                                                  1        2  \
# 0 NaN                                                NaN      NaN
# 1 NaN                                                NaN      NaN
# 2 NaN  Published: 15 August 2022 | Version 1 | DOI: 1...      NaN
# 3 NaN  Description\nThese datasets were used to devel...      NaN
# 4 NaN                                                NaN      NaN
# 5 NaN                                        Pregnancies  Glucose
# 6 NaN                                                  6      148
# 7 NaN                                                  1       85
# 8 NaN                                                  8      183
# 9 NaN                                                  1       89
#
#                 3                  4        5                6  \
# 0             NaN                NaN      NaN              NaN
# 1             NaN  Diabetes Datasets      NaN              NaN
# ...

# %%
# Fila 5 contiene los nombres de las columnas reales (índice 5)
columnas = df_raw.iloc[5, 1:].tolist()

# Extraemos desde la fila 6 hasta la 774 (excluyendo las últimas 3 filas)
df = df_raw.iloc[6:774, 1:]  # <- NOTA: El índice 774 NO se incluye

# Asignamos nombres de columnas y reiniciamos índice
df.columns = columnas

df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 📊 **Diagnóstico de tipos de datos**
#
# Verificamos si los tipos de datos son apropiados. A veces los valores numéricos pueden haberse interpretado como texto.

# %%
print(f'Registros/Observaciones: {df.shape[0]}, Variables: {df.shape[1]}')
# Out:
# Registros/Observaciones: 768, Variables: 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 767 non-null    object
#  1   Glucose                     768 non-null    object
#  2   Blood pressure              765 non-null    object
#  3   Skin thickness              765 non-null    object
#  4   Insulin                     766 non-null    object
#  5   Body mass index             766 non-null    object
#  6   Diabetes pedigree function  762 non-null    object
#  7   Age                         765 non-null    object
#  8   Outcome                     768 non-null    object
# dtypes: object(9)
# memory usage: 54.1+ KB

# %% [markdown]
# ### **🚫 Datos Nulos**
#
# Identificamos a cantidad de valores nulos

# %%
df.isna().sum()
# Out:
# Pregnancies                   1
# Glucose                       0
# Blood pressure                3
# Skin thickness                3
# Insulin                       2
# Body mass index               2
# Diabetes pedigree function    6
# Age                           3
# Outcome                       0
# dtype: int64

# %% [markdown]
# ### 🧼 **Limpieza de columnas**
#
# Recomendamos limpiar espacios en los nombres de columnas para evitar errores luego.

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# ### **⚙️ Tratamiento de valores nulos (ejemplo con imputación)**
#
# Ahora sí, aplicamos herramientas para diagnosticar calidad de los datos:

# %%
# Imputación con mediana en algunas columnas comunes
columnas_a_imputar = ['pregnancies',  'glucose',  'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'diabetes_pedigree_function', 'age']

for col in columnas_a_imputar:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # asegurar tipo numérico

    df[col].fillna(df[col].median(), inplace=True)
# Out:
# <ipython-input-15-0e2a68b068e8>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %% [markdown]
# <font size = 5>↘️ Otras Estrategias de Imputación:</font>

# %% [markdown]
# <font size = 5>🔸Imputación con media o mediana de una sola columna:

# %%
df['glucose'].fillna(df['glucose'].mean(), inplace=True)
# Out:
# <ipython-input-16-34333e6848ea>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['glucose'].fillna(df['glucose'].mean(), inplace=True)

# %% [markdown]
# <font size = 5>🔸Imputación por regresión
#  - Veremos un ejemplo en Misión 2
#
# <font size = 5>🔸Descarte de filas/columnas:

# %%
df_sin_nulos = df.dropna()

# %% [markdown]
# <font size = 5>🔸KNNImputer - similar más cercano:
#
# ¿Cómo funciona el **KNNImputer**?
#
# KNN utiliza el algoritmo de <u>**k vecinos más cercanos** (k-Nearest Neighbors)</u> para imputar valores faltantes:
#
# **Enfoque:** Rellena los valores faltantes considerando los valores de los k registros más similares en el conjunto de datos.
#
# **Funcionamiento:** Para cada observación con un valor faltante, busca las k observaciones más similares (usando las características disponibles) y usa sus valores para estimar el valor faltante.
#
# **Ventajas:** Considera la estructura multidimensional de los datos y las relaciones entre variables.

# %%
import pandas as pd
import numpy as np

# Carga de los Datos
url = 'https://github.com/juliandariogiraldoocampo/ia_taltech/raw/refs/heads/main/Dataset%201%20_%20Pima%20Indians%20diabetes%20dataset%20(PIDD)_modificado.xlsx'

# Cargar la hoja sin asumir encabezados
df_raw = pd.read_excel(url, header=None) # En caso de no querer cargar los encabezados del archivo

# Fila 5 contiene los nombres de las columnas reales (índice 5)
columnas = df_raw.iloc[5, 1:].tolist()

# Extraemos desde la fila 6 hasta la 774 (excluyendo las últimas 3 filas)
df = df_raw.iloc[6:774, 1:]  # <- NOTA: El índice 774 NO se incluye

# Asignamos nombres de columnas y reiniciamos índice
df.columns = columnas

df.reset_index(drop=True, inplace=True)

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

columnas_a_imputar = ['pregnancies',  'glucose',  'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'diabetes_pedigree_function', 'age']

for col in columnas_a_imputar:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # asegurar tipo numérico

    df[col] = df[col].replace(0, np.nan)

df.head(10)
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0          6.0    148.0            72.0            35.0      NaN
# 1          1.0     85.0            66.0            29.0      NaN
# 2          8.0    183.0            64.0             NaN      NaN
# 3          1.0     89.0            66.0            23.0     94.0
# 4          NaN    137.0            40.0            35.0    168.0
# 5          5.0    116.0            74.0             NaN      NaN
# 6          3.0     78.0            50.0            32.0     88.0
# 7         10.0    115.0             NaN             NaN      NaN
# 8          2.0    197.0            70.0            45.0    543.0
# 9          8.0    125.0            96.0             NaN      NaN
#
#    body_mass_index  diabetes_pedigree_function   age outcome
# 0             33.6                       0.627  50.0       1
# 1             26.6                       0.351  31.0       0
# 2             23.3                       0.672  32.0       1
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=3)
df_imputado = pd.DataFrame(imputer.fit_transform(df.select_dtypes(include='number')),
                           columns=df.select_dtypes(include='number').columns)

# %%
df_imputado
# Out:
#      pregnancies  glucose  blood_pressure  skin_thickness     insulin  \
# 0       6.000000    148.0            72.0       35.000000  125.333333
# 1       1.000000     85.0            66.0       29.000000   66.666667
# 2       8.000000    183.0            64.0       30.000000  195.000000
# 3       1.000000     89.0            66.0       23.000000   94.000000
# 4       7.666667    137.0            40.0       35.000000  168.000000
# ..           ...      ...             ...             ...         ...
# 763    10.000000    101.0            76.0       48.000000  180.000000
# 764     2.000000    122.0            70.0       27.000000  166.666667
# 765     5.000000    121.0            72.0       23.000000  112.000000
# 766     1.000000    126.0            60.0       35.333333  120.666667
# 767     1.000000     93.0            70.0       31.000000   70.666667
#
#      body_mass_index  diabetes_pedigree_function   age
# 0               33.6                       0.627  50.0
# ...

# %% [markdown]
# <font size = 5>**Observación:**
#
# Los valores obtenidos tienen este comportamiento porque el algoritmo:
#
# - Identifica los 3 registros más similares al registro 4 considerando todas las otras columnas numéricas (glucose, blood_pressure, etc.)
# - Toma el promedio de "pregnancies" de esos 3 registros similares
#
# <font size = 5>**¿Por qué los resultados son así?**
#
# **Promedios de vecinos:** Los valores decimales largos (como 125.333333) son el resultado directo de promediar 3 valores de los vecinos más cercanos.
#
# **Similitud multidimensional:** <u>**KNNImputer no considera solo una columna a la vez**</u>, sino la similitud general basada en todas las variables disponibles. Esto significa que los "vecinos" se determinan por la cercanía en un espacio multidimensional.
#
# **Valores consistentes**: La imputación es consistente con las relaciones entre variables. Por ejemplo, si pacientes con glucosa alta tienden a tener insulina al
# ta, el algoritmo captura esta relación.
#
# **Preservación de la distribución:** Los valores imputados mantienen propiedades estadísticas similares a los datos originales, sin introducir valores extremos o irrealistas.
#
# Este enfoque es más sofisticado que métodos de propagación como ffill o bfill porque considera las relaciones entre múltiples variables, en lugar de  usar valores adyacentes en una secuencia.

# %% [markdown]
# <font size = 5>🔸Propagación del Anterior o del Siguiente
#
# <font size = 4>**ffill (forward fill)**
#
# Propaga el último valor válido hacia adelante para rellenar valores faltantes subsiguientes.
#
# **Funcionamiento:** Cuando encuentra un valor faltante, lo reemplaza con el valor válido anterior más reciente.
#
# **Uso típico:** df.fillna(method='ffill') o df.ffill()
#
# **Contexto ideal:** Series temporales donde es razonable asumir que un valor faltante es similar al valor anterior.
# <hr>
#
# <font size = 4>**bfill (backward fill)**
#
# Propaga el siguiente valor válido hacia atrás para rellenar valores faltantes anteriores.
#
# **Funcionamiento:** Cuando encuentra un valor faltante, lo reemplaza con el próximo valor válido.
#
# **Uso típico:** df.fillna(method='bfill') o df.bfill()
#
# **Contexto ideal:** Cuando es razonable asumir que un valor faltante es similar al valor que viene después.

# %% [markdown]
# ### **👁️ Verificación final**
#
#
# Verificamos si el dataset ya está limpio y preparado para análisis exploratorio.

# %%
print(df.isnull().sum())
# Out:
# pregnancies                   112
# glucose                         5
# blood_pressure                 37
# skin_thickness                229
# insulin                       374
# body_mass_index                13
# diabetes_pedigree_function      6
# age                             3
# outcome                         0
# dtype: int64

# %%
df.describe()
# Out:
#        pregnancies     glucose  blood_pressure  skin_thickness     insulin  \
# count   656.000000  763.000000      731.000000      539.000000  394.000000
# mean      4.500000  121.686763       72.406293       29.220779  155.548223
# std       3.216845   30.535641       12.388037       10.437700  118.775855
# min       1.000000   44.000000       24.000000        7.000000   14.000000
# 25%       2.000000   99.000000       64.000000       22.000000   76.250000
# 50%       4.000000  117.000000       72.000000       29.000000  125.000000
# 75%       7.000000  141.000000       80.000000       36.000000  190.000000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#        body_mass_index  diabetes_pedigree_function         age
# count       755.000000                  762.000000  765.000000
# mean         32.457483                    0.472517   33.264052
# std           6.932502                    0.332047   11.773421
# ...

# %% [markdown]
# <hr><center><font size = 6> 🚨 </font><font size = 4>Es posible que identifique que algunas de las variables tienen valores mínimos que no son consistentes con la realidad
#
# *(Guiño Guiño... hay unas 5 variables con esa condición... como lo resolvemos?)*
# <hr>

# %% [markdown]
# ### **↘️ Imputar datos por valores inconsistentes en "cero"**

# %% [markdown]
# <font size = 4>🧠 Solución: Imputar usando el Vecino más Cercano (KNN Imputer)
#
# <font size = 4>Vamos a:
# - <font size = 4>Reemplazar los ceros por np.nan en las columnas relevantes.
# - <font size = 4>Usar `KNNImputer` de `sklearn.impute` para completar los valores faltantes.

# %% [markdown]
# 🚩 **Paso 1: Reemplazar ceros por NaN**

# %%
import numpy as np

# Variables en las que 0 significa dato faltante
variables_faltantes = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index']

# Reemplazar 0 por np.nan
df[variables_faltantes] = df[variables_faltantes].replace(0, np.nan)

# %% [markdown]
# 🚩 **Paso 2: Imputar con vecinos más cercanos (KNN)**

# %%
from sklearn.impute import KNNImputer

# Crear el imputador
imputer = KNNImputer(n_neighbors=5)

# Aplicar imputación
df_imputado = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %% [markdown]
# ## **<font size = 5>✅ Reto 3. Normalización de Datos**
#
# **🔍 Introducción a la Normalización de Datos**
#
# En el contexto del machine learning, la normalización es un paso crítico en el preprocesamiento de datos que consiste en ajustar las escalas de las variables numéricas para que todas compartan un rango o distribución similar.
#
# **¿Por qué es importante?**
#
# - **Evita sesgos en los modelos:** Algoritmos como K-Nearest Neighbors (KNN), Support Vector Machines (SVM) o Principal Component Analysis (PCA) son sensibles a las diferencias de magnitud entre variables. Por ejemplo, si una variable (como "ingresos anuales") está en miles y otra (como "edad") en decenas, el modelo podría sobrevalorar la primera simplemente por su escala numérica.
#
# - **Mejora la convergencia:** En modelos basados en gradiente descendente (como redes neuronales), la normalización acelera el entrenamiento al equilibrar la velocidad de actualización de los pesos.
#
# - **Facilita comparaciones**: Permite interpretar coeficientes o importancias de características de manera más justa.
#
# **Casos de uso común**
#
# - Variables como glucosa (mg/dL), presión arterial (mmHg) e índice de masa corporal (kg/m²) suelen estar en escalas muy distintas. Normalizarlas asegura que ninguna domine el modelo artificialmente.
#
# > <font size=5>💡Para tener en cuenta:</font><br>
# > *La normalización es una técnica fundamental para garantizar que los datos estén en condiciones óptimas antes de entrenar modelos, especialmente cuando las variables tienen unidades o rangos dispares.*<br>
# <i>**Nota:** Las técnicas más usadas incluyen `StandardScaler` (media=0, desviación=1) y `MinMaxScaler` (escala [0, 1]). Elegir una u otra depende del algoritmo y la distribución de los datos.

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

########## CARGA DE DATOS
url = 'https://github.com/juliandariogiraldoocampo/ia_taltech/raw/refs/heads/main/Dataset%201%20_%20Pima%20Indians%20diabetes%20dataset%20(PIDD)_modificado.xlsx'

# Cargar la hoja sin asumir encabezados
df_raw = pd.read_excel(url, header=None) # En caso de no querer cargar los encabezados del archivo

# Fila 5 contiene los nombres de las columnas reales (índice 5)
columnas = df_raw.iloc[5, 1:].tolist()


########## LIMPIEZA
# Extraemos desde la fila 6 hasta la 774 (excluyendo las últimas 3 filas)
df = df_raw.iloc[6:774, 1:]  # <- NOTA: El índice 774 NO se incluye

# Asignamos nombres de columnas y reiniciamos índice
df.columns = columnas

df.reset_index(drop=True, inplace=True)

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

columnas_a_imputar = ['pregnancies',  'glucose',  'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'diabetes_pedigree_function', 'age']


########## IMPUTACION
for col in columnas_a_imputar:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # asegurar tipo numérico

    df[col] = df[col].replace(0, np.nan)

# Crear el imputador
imputer = KNNImputer(n_neighbors=5)

# Aplicar imputación
df_imputado = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

df = df_imputado

# %%
df
# Out:
#      pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0            6.0    148.0            72.0            35.0    169.0
# 1            1.0     85.0            66.0            29.0     58.6
# 2            8.0    183.0            64.0            25.8    164.6
# 3            1.0     89.0            66.0            23.0     94.0
# 4            7.6    137.0            40.0            35.0    168.0
# ..           ...      ...             ...             ...      ...
# 763         10.0    101.0            76.0            48.0    180.0
# 764          2.0    122.0            70.0            27.0    165.0
# 765          5.0    121.0            72.0            23.0    112.0
# 766          1.0    126.0            60.0            35.2    134.2
# 767          1.0     93.0            70.0            31.0     66.6
#
#      body_mass_index  diabetes_pedigree_function   age  outcome
# 0               33.6                       0.627  50.0      1.0
# ...

# %% [markdown]
# #### <font size = 5> ↘️ Normalizacion

# %% [markdown]
# ### **🔹 1. MinMaxScaler**
# Escala los valores al rango [0, 1].

# %%
from sklearn.preprocessing import MinMaxScaler

# Seleccionamos variables numéricas a escalar
variables = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index']

# Creamos el objeto scaler
scaler_minmax = MinMaxScaler()

# Ajustamos y transformamos los datos
df_minmax = df.copy()
df_minmax[variables] = scaler_minmax.fit_transform(df[variables])

# Vista previa de los resultados
df_minmax[variables].head()
# Out:
#     glucose  blood_pressure  skin_thickness   insulin  body_mass_index
# 0  0.670968        0.489796        0.304348  0.186298         0.314928
# 1  0.264516        0.428571        0.239130  0.053606         0.171779
# 2  0.896774        0.408163        0.204348  0.181010         0.104294
# 3  0.290323        0.428571        0.173913  0.096154         0.202454
# 4  0.600000        0.163265        0.304348  0.185096         0.509202

# %% [markdown]
# ### **🔹 2. RobustScaler**
# Útil cuando hay valores atípicos (outliers). Escala según la mediana y el rango intercuartílico (IQR).
#
# $$
# X_{scaled} = \frac{X - \text{mediana} (X)} {Q3 - Q1}
# $$

# %%
from sklearn.preprocessing import RobustScaler

scaler_robust = RobustScaler()
df_robust = df.copy()
df_robust[variables] = scaler_robust.fit_transform(df_robust[variables])

# Vista previa
df_robust[variables].head()
# Out:
#     glucose  blood_pressure  skin_thickness   insulin  body_mass_index
# 0  0.751515           0.000        0.500000  0.352711         0.142857
# 1 -0.775758          -0.375        0.000000 -0.725940        -0.626374
# 2  1.600000          -0.500       -0.266667  0.309722        -0.989011
# 3 -0.678788          -0.375       -0.500000 -0.380068        -0.461538
# 4  0.484848          -2.000        0.500000  0.342941         1.186813

# %% [markdown]
# ## **<font size = 5>✅ Reto 4. Análisis Univariable**
#
# El análisis univariable es el primer paso en la exploración de datos (EDA), donde se estudia una variable a la vez para entender su comportamiento, distribución y características clave. Este enfoque permite:
#
# - Identificar patrones o tendencias en los datos.
#
# - Detectar valores atípicos (outliers) o errores en la medición.
#
# - Evaluar la dispersión y el centro de los datos (media, mediana, moda, rango, desviación estándar).
#
# - Preparar los datos para etapas posteriores, como el modelado estadístico o de machine learning.

# %%
# Estadísticas individuales más detalladas
from scipy.stats import skew, kurtosis

columna = 'glucose'
print(f"Asimetría (skew) de {columna}: ", skew(df[columna], nan_policy='omit'))
print(f"Curtosis de {columna}: ", kurtosis(df[columna], nan_policy='omit'))
# Out:
# Asimetría (skew) de glucose:  0.5337982914643553
# Curtosis de glucose:  -0.27683984183393795

# %% [markdown]
# **🔍 ¿Qué es la Curtosis?**
#
# La curtosis (o kurtosis) es una medida estadística que cuantifica qué tan "pesadas" o ligeras son las colas de una distribución comparada con la distribución normal (gaussiana). Indica la presencia de valores extremos (outliers) y la concentración de datos alrededor de la media. Se interpreta así:
#
# - **Curtosis = 0**: La distribución tiene colas similares a la normal (mesocúrtica).
#
# - **Curtosis > 0**: Colas más pesadas y pico más agudo (leptocúrtica → más outliers).
#
# - **Curtosis < 0**: Colas más ligeras y pico más aplanado (platicúrtica → menos outliers).
#
# **🤔 ¿Para qué sirve esto?**
# - Identificar distribuciones no normales: Ayuda a decidir si aplicar transformaciones (ej: logarítmica).
#
# - Preparar datos para modelos: Algoritmos como SVM o KNN son sensibles a asimetría y outliers.
#
# - Detectar anomalías: Curtosis alta sugiere presencia de valores extremos.
#
# > <font size = 6>💡</font>*Transformamos datos no normales para que los modelos de machine learning funcionen mejor. Si los datos están muy cargados a un lado o tienen valores extremos, los algoritmos pueden cometer errores o volverse lentos. <br><br>
# Usamos transformaciones sencillas (como el logaritmo o la raíz cuadrada) para **"suavizar" esos datos y que se parezcan más a una campana de Gauss**, lo que ayuda a los modelos a aprender patrones de manera más precisa.*

# %% [markdown]
# ### **Visualización con histogramas, boxplots y KDE**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma + KDE (estimación de densidad)
sns.histplot(data=df, x='glucose', kde=True)
plt.title('Distribución de Glucosa')
plt.show()

# %% [markdown]
# <font size = 5> 🤔 **Ejemplo de Interpretación:**
#
# **Histograma (barras):** Frecuencia de valores de glucosa en rangos específicos (ej: ~60 personas tienen entre 90-100 mg/dL).
#
# **Línea KDE (curva):** Tendencia suavizada de la distribución (pico ≈ moda, donde se concentran más datos).
#
# **Hallazgos clave:**
#
# - Distribución casi normal, con mayoría de valores entre 80-120 mg/dL.
#
# - Cola derecha leve: Algunos casos de glucosa alta (>140 mg/dL), pero sin outliers extremos.
#
# - Sin valores anómalos bajos (<40 mg/dL).

# %%
# Diagrama de caja para detectar outliers
sns.boxplot(data=df, x='glucose')
plt.title('Boxplot de Glucosa')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Configuración del estilo
sns.set(style="whitegrid")

# Crear figura más ancha
plt.figure(figsize=(10, 6))

# Boxplot
ax = sns.boxplot(data=df, x='glucose', color='skyblue')

# Calcular cuartiles y bigotes
q1, q2, q3 = np.percentile(df['glucose'], [25, 50, 75])
iqr = q3 - q1
upper_whisker = q3 + 1.5 * iqr
lower_whisker = q1 - 1.5 * iqr

# Anotaciones mejoradas
props = {'boxstyle': 'round', 'facecolor': 'white', 'alpha': 0.8, 'pad': 0.3}

ax.annotate(f'Q1: {q1:.1f}', xy=(q1, 0), xytext=(q1, -0.15),
            ha='center', va='top', fontsize=10,
            bbox=props, arrowprops=dict(arrowstyle='->'))

ax.annotate(f'Mediana: {q2:.1f}', xy=(q2, 0), xytext=(q2, -0.25),
            ha='center', va='top', fontsize=10, color='red',
            bbox=props, arrowprops=dict(arrowstyle='->'))

ax.annotate(f'Q3: {q3:.1f}', xy=(q3, 0), xytext=(q3, -0.15),
            ha='center', va='top', fontsize=10,
            bbox=props, arrowprops=dict(arrowstyle='->'))

ax.annotate(f'Límite superior: {upper_whisker:.1f}',
            xy=(upper_whisker, 0), xytext=(upper_whisker, -0.25),
            ha='center', va='top', fontsize=9, bbox=props,
            arrowprops=dict(arrowstyle='->'))

ax.annotate(f'Límite inferior: {lower_whisker:.1f}',
            xy=(lower_whisker, 0), xytext=(lower_whisker, -0.25),
            ha='center', va='top', fontsize=9, bbox=props,
            arrowprops=dict(arrowstyle='->'))

plt.title('Distribución de Glucosa con Cuartiles', pad=20)
plt.xlabel('Nivel de Glucosa (mg/dL)')
plt.yticks([])
sns.despine(left=True)
plt.tight_layout()

plt.show()

# %% [markdown]
# <font size = 5> 🤔 **Ejemplo de Interpretación:**
#
# - **Rango normal:** La caja central (Q1=99 a Q3=141 mg/dL) contiene el 50% de los datos. La mediana (117 mg/dL) indica que la mitad de las mediciones están por debajo de este valor.
#
# - **Bigotes y outliers:** Los límites inferior (44 mg/dL) y superior (204 mg/dL) definen el rango esperado. Valores fuera de este rango (como los cercanos a 40 o 200 mg/dL) serían atípicos, posiblemente indicando hipoglucemia o hiperglucemia.
#
# - **La asimetría:** (mediana desplazada hacia Q1) sugiere que hay más concentración de valores bajos que altos, pero sin outliers extremos. Ideal para detectar patrones clínicos rápidamente.

# %% [markdown]
# ### <font size = 5> **Validación de normalidad**

# %% [markdown]
# #### 🔸 Test de Shapiro-Wilk:
#
# Evalúa si una muestra proviene de una distribución normal.
#
# <i><b>Uso ideal:</b> Para muestras pequeñas (típicamente < 5000 datos).</i>

# %%
from scipy.stats import shapiro

stat, p = shapiro(df['glucose'])
print(f'Estadístico de Shapiro-Wilk: {stat:.4f}, valor p: {p:.4f}')

if p > 0.05:
    print('Distribución normal (no se rechaza H0)')
else:
    print('Distribución no normal (se rechaza H0)')
# Out:
# Estadístico de Shapiro-Wilk: 0.9694, valor p: 0.0000
# Distribución no normal (se rechaza H0)

# %% [markdown]
# ####🔸 Test de Pearson:
#
# Combina asimetría (skew) y curtosis (kurtosis) para evaluar normalidad.
#
# <i><b>Uso ideal:</b> Para muestras más grandes (> 20 datos, recomendable >50).</i>

# %%
from scipy.stats import normaltest

stat, p = normaltest(df['glucose'])
print("p-value:", p)  # Si p < 0.05, rechaza normalidad
# Out:
# p-value: 1.637752044126254e-08

# %% [markdown]
# #### **Hipótesis nula (H0) vs. Hipótesis alternativa (H1)**
#
# - **Hipótesis nula (H0):** Es la "posición por defecto" que asumimos inicialmente.
#
#  Ejemplo: "Los niveles de glucosa siguen una distribución normal".
#
# - **Hipótesis alternativa (H1):** Es lo que queremos probar (lo opuesto a H0).
#
#  Ejemplo: "Los niveles de glucosa no siguen una distribución normal".
# ---
# **Interpretación clave (independiente del test):**
#
# 1. **Si la evidencia (p-value) es débil (p > 0.05):**
#
#  No podemos rechazar H0 (no hay pruebas suficientes para descartar la normalidad).
#
#  No significa que H0 sea verdadera, solo que no hay datos contundentes en contra.
#
# 2. **Si la evidencia es fuerte (p ≤ 0.05):**
#
#  Rechazamos H0 (hay suficiente apoyo para H1).
#
#  Conclusión: Los datos se desvían significativamente de la normalidad.
#
# **Analogía médica:**
#
# - H0: "El paciente está sano".
# - H1: "El paciente tiene una condición".
# - p-value: Resultado de un examen diagnóstico.
#
#  - p > 0.05: "No hay hallazgos concluyentes para diagnosticar la condición".
#
#  - p ≤ 0.05: "Hallazgos sugieren la presencia de la condición".
#
# > <font size = 4>🚨**Pilas con esto:** <br>
# > - <font size = 4>H0/H1 son afirmaciones sobre la población, **no sobre la muestra**.
# > - <font size = 4>Nunca se "prueba" H0, solo se evalúa si hay evidencia suficiente para rechazarla.
# > - <font size = 4>¡Esto aplica a cualquier test de hipótesis, no solo a normalidad!

# %% [markdown]
# #### **Otro ejemplo de H0 y H1**
#
# **Analogía del Detective (Juicio Penal)**
# - **H0 (Hipótesis nula):** "El acusado es inocente" (como en "inocente hasta que se pruebe lo contrario").
# - **H1 (Hipótesis alternativa):** "El acusado es culpable".
# - **p-value:** La fuerza de la evidencia (huellas, testigos, ADN).
#  - Si p > 0.05: Evidencia débil → No condenas (no rechazas H0: "inocente").
#  - Si p ≤ 0.05: Evidencia sólida → Condenas (rechazas H0: "culpable").
#
# **<font size = 4>🚨Ojo, esto es clave:**
#
# - Nunca pruebas la inocencia (H0), solo buscas pruebas contra ella.
# - Un veredicto de "no culpable" <font size = 5>≠</font> "inocente", solo que no hubo pruebas suficientes.

# %% [markdown]
# ### 📊 **Tabla de decisión:**
#
# Test de normalidad por tamaño de muestra
#
# | <font size = 3>Tamaño de la Muestra | <font size = 3>Test Recomendado           | <font size = 3>Razón                                                                 |
# |-----------------------|----------------------------|-----------------------------------------------------------------------|
# | <font size = 3>**n < 50**           | <font size = 3>`shapiro()` (Shapiro-Wilk) | <font size = 3>Más sensible para detectar no-normalidad en muestras pequeñas.        |
# | <font size = 3>**50 ≤ n ≤ 5,000**   | <font size = 3>`normaltest()` (D'Agostino-Pearson) | <font size = 3>Combina *skew* y *kurtosis*; robusto para muestras medianas.          |
# | <font size = 3>**n > 5,000**        | <font size = 3>Gráficos (QQ-plot, histograma) + `normaltest()` | <font size = 3>Los tests pueden ser demasiado sensibles; prioriza visualización.     |
# <br>
#
# **Notas**:
# - Para **n < 20**, considera pruebas no paramétricas o transformaciones automáticas.
# - Si el p-value es **< 0.05**, rechaza normalidad (pero evalúa el impacto real en tu modelo).

# %% [markdown]
# ### 📊 **¿Qué es el p-value?**
#
# El p-value (valor de p) es un número entre 0 y 1 que nos dice si los datos siguen una distribución normal (en forma de "campana de Gauss").
#
# **Interpretación:**
#
# - Si p-value > 0.05: Los datos probablemente son normales ("aceptamos" la normalidad).
# - Si p-value ≤ 0.05: Los datos no son normales (hay evidencia para rechazar la normalidad).
# ---
# 🧪 Comparación con un Examen Médico
# Imaginemos que estos tests son como pruebas diagnósticas:
#
# **1. Shapiro-Wilk (para muestras pequeñas, <50 datos):**
# - Similar a un test rápido de glucosa. Es preciso con pocas muestras, pero pierde sensibilidad si hay muchos datos.
# - Ejemplo: Si p = 0.03 → "Hay evidencia de que los datos no son normales" (como un test positivo para una anomalía).
#
# **2. D'Agostino-Pearson (para muestras más grandes):**
# - Similar a un panel metabólico completo. Evalúa dos aspectos:
#  - Asimetría (si la curva está desplazada a izquierda/derecha).
#  - Curtosis (si las colas son más gruesas o planas que lo normal).
# - Ejemplo: Si p = 0.20 → "No hay evidencia suficiente para decir que los datos no son normales" (como un resultado negativo en un examen).
#
# 📊 **¿Por qué importa en investigación clínica?**
# Muchos análisis estadísticos (como el t-test o ANOVA) asumen normalidad. Si el p-value ≤ 0.05:
# - Alternativas: Usar pruebas no paramétricas (Mann-Whitney, Kruskal-Wallis).
# > Las pruebas no paramétricas son métodos estadísticos que no asumen una distribución normal en los datos y se usan **cuando los datos son ordinales** o **no cumplen los requisitos de las pruebas tradicionales**.
# > Ejemplos comunes:
# > - Prueba de Mann-Whitney (comparar 2 grupos)
# > - Prueba de Kruskal-Wallis (comparar 3+ grupos)
# > - Prueba de Wilcoxon (datos pareados)
# > Ventaja clave: Funcionan bien con muestras pequeñas o datos atípicos.
# - Transformar datos: Aplicar logaritmo para normalizar.

# %% [markdown]
# ## **<font size = 5>✅ Reto 5. Análisis Bivariado**
#
# El análisis bivariado explora relaciones entre dos variables para identificar patrones clave:
#
# - **Correlaciones:** ¿Aumentan/disminuyen juntas? (ej: glucosa vs. edad).
#
# - **Redundancia**: ¿Variables repetitivas? (ej: peso vs. IMC).
#
# - **Patrones clínicos:** ¿Asociaciones relevantes? (ej: presión arterial alta con diabetes).
#
# ---
# **🛠️ Herramientas comunes:** Gráficos de dispersión, heatmaps de correlación o boxplots comparativos.

# %% [markdown]
# ### EL CODIGO

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

########## CARGA DE DATOS
url = 'https://github.com/juliandariogiraldoocampo/ia_taltech/raw/refs/heads/main/Dataset%201%20_%20Pima%20Indians%20diabetes%20dataset%20(PIDD)_modificado.xlsx'

# Cargar la hoja sin asumir encabezados
df_raw = pd.read_excel(url, header=None) # En caso de no querer cargar los encabezados del archivo

# Fila 5 contiene los nombres de las columnas reales (índice 5)
columnas = df_raw.iloc[5, 1:].tolist()


########## LIMPIEZA
# Extraemos desde la fila 6 hasta la 774 (excluyendo las últimas 3 filas)
df = df_raw.iloc[6:774, 1:]  # <- NOTA: El índice 774 NO se incluye

# Asignamos nombres de columnas y reiniciamos índice
df.columns = columnas

df.reset_index(drop=True, inplace=True)

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

columnas_a_imputar = ['pregnancies',  'glucose',  'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'diabetes_pedigree_function', 'age']


########## IMPUTACION
for col in columnas_a_imputar:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # asegurar tipo numérico

    df[col] = df[col].replace(0, np.nan)

# Crear el imputador
imputer = KNNImputer(n_neighbors=5)

# Aplicar imputación
df_imputado = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

df = df_imputado

# %% [markdown]
# ### 🔹  **Matriz de Correlación**

# %%
# Visualizar matriz de correlación
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular matriz de correlación
matriz_correlacion = df.corr()

plt.figure(figsize=(8,6))
sns.heatmap(matriz_correlacion,
            annot=True,
            cmap='Spectral',
            fmt='.2f')
plt.title('Matriz de Correlación entre Variables')
plt.show()

# %% [markdown]
# <font size = 5> 🤔 **Ejemplo de Interpretación:**
#
# 1. **Correlaciones fuertes (>0.5):**
#
#  - glucose e insulin (0.61): Niveles altos de glucosa suelen coincidir con alta insulina.
#
#  - skin_thickness y body_mass_index (0.64): Grosor de piel y BMI están relacionados (ambos indican adiposidad).
#
#  - pregnancies y age (0.55): Mujeres con más embarazos tienden a ser mayores.
#
# 2. **Correlaciones débiles (<0.3):**
#
#  - diabetes_pedigree_function casi no se correlaciona con otras variables (valores ≈0).
#
#  - blood_pressure muestra relaciones moderadas con otras variables (0.22 a 0.34).
#
# 3. **Variables redundantes:**
#
#  - skin_thickness y body_mass_index (0.64) podrían medir aspectos similares (grasa corporal).
# <br>
#
# **🚨 Alertas para modelado**
# - **Multicolinealidad:** Las correlaciones altas (ej: 0.61, 0.64) pueden distorsionar modelos lineales.
# - **Variables irrelevantes:**
#  - diabetes_pedigree_function aporta poca información (correlaciones ≈0).
# <br>
#
# **📌 Acciones recomendadas**
# - Para modelos predictivos:
#  - Eliminar una de cada par de variables altamente correlacionadas (ej: conservar solo body_mass_index y descartar skin_thickness).
#
# - Para análisis clínicos:
#  - Investigar por qué glucose e insulin están tan ligadas (¿resistencia a la insulina?).

# %% [markdown]
# ### 🔹  **Gráfico de Dispersión**

# %%
# Relación entre glucosa e insulina
sns.scatterplot(data=df, x='glucose', y='insulin')
plt.title('Relación entre Glucosa e Insulina')
plt.show()

# %% [markdown]
# <font size = 5> 🤔 **Ejemplo de Interpretación Visual del Gráfico de Dispersión**
#
#  - **1. Ejes y Datos**
#
#  - Eje X (glucosa): Valores de glucosa en sangre (40-200 mg/dL).
#
#  - Eje Y (insulina): Niveles de insulina (0-800 μU/mL).
#
#  - Cada punto: Un paciente con sus mediciones de glucosa e insulina.
#
# 2. **Patrón General**
#
#  - Tendencia ascendente: La mayoría de puntos suben hacia la derecha.
#
#  - Interpretación: A mayor glucosa, mayor insulina (relación positiva).
#
# 3. **Zonas Clave**
#
#  **Zona verde (normal):**
#   - Glucosa: 70-120 mg/dL
#   - Insulina: 50-200 μU/mL
#   - Pacientes probablemente sanos.
#
#  **Zona roja (alerta):**
#  - Glucosa > 140 mg/dL + Insulina baja (<50 μU/mL).
#  - Posible diabetes (cuerpo no produce suficiente insulina).
#
#  **Zona amarilla (curiosa):**
#  - Glucosa normal (100-120 mg/dL) + Insulina muy alta (>400 μU/mL).
#  - Posible resistencia a la insulina (cuerpo trabaja demasiado para compensar).
#
# 4. **Outliers Extremos**
#
#  Puntos aislados en la esquina superior derecha (glucosa e insulina altísimas):
#  - Casos graves que requieren atención urgente.
#
# 5. **Vacíos**
#  Pocos puntos con glucosa baja (<60 mg/dL):
#  - Datos faltantes o pacientes bien controlados.

# %% [markdown]
# ## **<font size = 5>✅ Reto 6. PCA - Análisis de Componentes Principales**
#
# PCA es una técnica que simplifica datos complejos al combinar variables correlacionadas en nuevos ejes ("componentes principales"), ordenados por la varianza que explican. Dico de optra forma, combina variables correlacionadas (ej: glucosa/insulina) en componentes simplificados que capturan la esencia de los datos.
#
# **Objetivos Clave**
#
# - **Reducir dimensiones:**
#
#  Transformar 10+ variables en solo 2-3 componentes sin perder información crítica.
#
# - **Capturar varianza:**
#
#  El primer componente (PC1) explica la mayor variabilidad; el segundo (PC2) la siguiente, y así sucesivamente.
#
# - **Visualizar patrones:**
#
#  Graficar datos en 2D/3D para identificar agrupaciones naturales (ej: pacientes sanos vs. diabéticos).
#
# **¿Por qué usar PCA?**
#
# - **Elimina redundancia:** Variables como glucosa e insulina (correlacionadas) se fusionan en un componente.
#
# - **Optimiza modelos:** Menos dimensiones = menos sobreajuste + mayor velocidad.
#
# - **Revela estructura oculta:** Agrupaciones no visibles en altas dimensiones.
#
#  ><b><i>Ejemplo clínico:</b> <br>
#  Si PC1 combina glu cosa, insulina y edad, podría interpretarse como un "factor de riesgo metabólico".</i>
#
#  > ⚠️ Consideraciones
#  > - Escala tus datos antes de aplicar PCA (usar StandardScaler).
#  > - Interpretabilidad: Los componentes son combinaciones matemáticas, no variables médicas directas.

# %% [markdown]
# ### 🔹 Paso 1: Estandarización de las variables
# PCA requiere que las variables estén en la misma escala.

# %%
from sklearn.preprocessing import StandardScaler

# Selección de variables numéricas
variables = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'age']

# Estandarización
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[variables])

# %% [markdown]
# ### 🔹 Paso 2: Aplicar PCA

# %%
from sklearn.decomposition import PCA

# Inicializar PCA para dos componentes
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Crear DataFrame con componentes
df_pca = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])

# %% [markdown]
# ### 🔹 Paso 3: Visualizar componentes principales

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df_pca, x='PC1', y='PC2')
plt.title('Visualización PCA - 2 Componentes Principales')
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} varianza)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} varianza)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 📊 Paso 4: Interpretación de varianza explicada

# %%
# Porcentaje de varianza explicada por cada componente
print('Varianza explicada:', pca.explained_variance_ratio_)

# %% [markdown]
# ❓❓❓<font size = 5>¿Cuántos componentes necesitas para explicar el 80% de la varianza?

# %%
# PCA sin limitar componentes
pca_full = PCA()
pca_full.fit(X_scaled)

# Varianza explicada por cada componente
print(pca_full.explained_variance_ratio_)
# Out:
# [0.40158107 0.20523309 0.1713778  0.10548213 0.0614891  0.0548368 ]

# %% [markdown]
# ### ✅ ¿Cómo saber cuántos componentes elegir en PCA?
#
# El número de componentes (n_components) se elige con base en cuánta varianza total del dataset explica cada componente principal.

# %% [markdown]
# ####🔸 Paso clave: no fijar `n_components inicialmente`

# %%
# PCA sin limitar componentes
pca_todos = PCA()
pca_todos.fit(X_scaled)

# Varianza explicada por cada componente
print(pca_todos.explained_variance_ratio_)
# Out:
# [0.40158107 0.20523309 0.1713778  0.10548213 0.0614891  0.0548368 ]

# %% [markdown]
# ####🔸 ¿Cómo visualizar cuántos componentes usar?

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.cumsum(pca_full.explained_variance_ratio_), marker='o')
plt.xlabel('Número de Componentes')
plt.ylabel('Varianza Acumulada')
plt.title('VARIANZA EXPLICADA ACUMULADA\n')
plt.grid(True)
plt.show()

# %%
pca = PCA(n_components=6)
pca.fit(X_scaled)
pca.explained_variance_ratio_  # Devuelve una lista con la varianza explicada de PC1 y PC2
for i, var in enumerate(pca.explained_variance_ratio_):
    print(f'PC{i+1}: {var:.2%}')
# Out:
# PC1: 40.16%
# PC2: 20.52%
# PC3: 17.14%
# PC4: 10.55%
# PC5: 6.15%
# PC6: 5.48%

# %% [markdown]
# ####🔸 Recomendación basada en contexto
#
# | Criterio                          | 3 Componentes (77.5%)       | 4 Componentes (88.1%)         |
# |----------------------------------|-----------------------------|-------------------------------|
# | 📊 Visualización (gráficos)     | ✔️ Posible en 3D (limitado) | ❌ Requiere técnicas más complejas |
# | 🧠 Interpretabilidad             | ✔️ Más sencilla             | ⚠️ Más difícil de interpretar |
# | 🤖 Preparación para modelado     | ⚠️ Algo de pérdida (~22%)   | ✔️ Mucho más completa         |
# | 🎯 Objetivo de este reto             | Didáctica + práctica        | Didáctica + profundidad técnica ✔️ |
#
#
# >✅ En este caso, usar 4 componentes (88.1%) es lo más recomendable, porque se acerca al umbral aceptado de 90% de varianza, pero aunque es ideal para **preprocesamiento para modelos predictivos reales**, es recomendable que ya dominemos PCA básico con 2 o 3 componentes.

# %% [markdown]
# ####🔸 "**BONUS**" - Gráfico en 3D
#
# Les dejo este código para que "jueguen" con el, y lo apliquen a sus propios conjuntos de datos.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# Variables seleccionadas
variables = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'age']

# Estandarización
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[variables])

# PCA con 3 componentes
pca_3d = PCA(n_components=3)
X_pca_3d = pca_3d.fit_transform(X_scaled)

# Crear DataFrame
df_pca_3d = pd.DataFrame(X_pca_3d, columns=['PC1', 'PC2', 'PC3'])

# Visualización 3D
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df_pca_3d['PC1'], df_pca_3d['PC2'], df_pca_3d['PC3'], alpha=0.6)

ax.set_xlabel(f'PC1 ({pca_3d.explained_variance_ratio_[0]:.2%})')
ax.set_ylabel(f'PC2 ({pca_3d.explained_variance_ratio_[1]:.2%})')
ax.set_zlabel(f'PC3 ({pca_3d.explained_variance_ratio_[2]:.2%})')
ax.set_title('Visualización PCA en 3D')

plt.tight_layout()
plt.show()

# %% [markdown]
# ####🔸 Y ahora uno interactivo...
#
# Pero, solo les queda como ejemplo, para que luego puedan explorarlo.

# %%
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Selección de variables
variables = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'body_mass_index', 'age']

# Estandarización
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[variables])

# PCA a 3 componentes
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

# DataFrame PCA
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2', 'PC3'])

# Gráfico 3D interactivo
fig = px.scatter_3d(df_pca,
                    x='PC1',
                    y='PC2',
                    z='PC3',
                    opacity=0.7,
                    title='PCA - Visualización Interactiva en 3D',
                    labels={
                        'PC1': f'PC1 ({pca.explained_variance_ratio_[0]:.2%})',
                        'PC2': f'PC2 ({pca.explained_variance_ratio_[1]:.2%})',
                        'PC3': f'PC3 ({pca.explained_variance_ratio_[2]:.2%})'
                    })

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
